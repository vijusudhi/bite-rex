# %%
import sys
sys.path.append('../')
from util import util, corpus, alignment, vectorize, retrieval, tokenize

from tqdm.notebook import tqdm as tq
import pandas as pd
# Out:
# [nltk_data] Downloading package stopwords to /home/sudhi/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /home/sudhi/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
scraped_df = util.decompress_pickle('../../data/other/scraped_df')
scraped_en_docs = util.decompress_pickle('../../data/other/scraped_en_docs')
scraped_de_docs = util.decompress_pickle('../../data/other/scraped_de_docs')

# %%
cont_en_doc_vectors = util.decompress_pickle('../../data/other/cont_en_doc_vectors')
cont_de_doc_vectors = util.decompress_pickle('../../data/other/cont_de_doc_vectors')

# %%
from sentence_transformers import SentenceTransformer

# %%
model = SentenceTransformer('../../data/other/cont_model/')

# %%
encoding = vectorize.Encoding(model=[model], model_type="sentence_bert")

# %%
cont_retrieval = vectorize.Retrieval(
    vectors=[cont_en_doc_vectors, cont_de_doc_vectors],
    docs=[scraped_en_docs, scraped_de_docs])

# %%
query = "adaptive cruise control"
query_vector = encoding.encode(sent=[query])
query_vector[0][:10]

# %%
retrieved = cont_retrieval.retrieve(query_vec=query_vector, num_ret=100)
# retrieved

# %%
from util import projection

# %%
en_vectors = [cont_en_doc_vectors[ind] for ind in retrieved['en_ind']]
de_vectors = [cont_de_doc_vectors[ind] for ind in retrieved['de_ind']]

# %%
# %%time
# run once, mayve save as pickle file
en_proj_2d = projection.get_projection_2d(cont_en_doc_vectors)
# de_proj_2d = projection.get_projection_2d(cont_de_doc_vectors)

# %%
def get_triplets(docs, proj_2d, indices):
    ret_colors = []
    ret_docs = []
    ret_projs = []
    for i in range(len(proj_2d)):
        if i not in indices:
            continue
        elif i in indices[:10]:
            ret_colors.append('red')
            ret_docs.append(docs[i])
            ret_projs.append(proj_2d[i])
        elif i in indices[90:]:
            ret_colors.append('blue')
            ret_docs.append(docs[i])
            ret_projs.append(proj_2d[i])    
    return ret_docs, ret_projs, ret_colors

# %%
ret_docs, ret_projs, ret_colors = get_triplets(scraped_en_docs, en_proj_2d, retrieved["en_ind"])
projection.plot_umap_2d(ret_docs, ret_projs, ret_colors)

# %%
ret_docs, ret_projs, ret_colors = get_triplets(scraped_de_docs, de_proj_2d, retrieved["de_ind"])
projection.plot_umap_2d(ret_docs, ret_projs, ret_colors)

# %%
vectors_comb = [] 
for vec in cont_en_doc_vectors:
    vectors_comb.append(vec)

for vec in cont_de_doc_vectors:
    vectors_comb.append(vec)
    
for vec in query_vector:
    vectors_comb.append(vec)
    
len(vectors_comb)

# %%
# %%time
proj_comb_2d = projection.get_projection_2d(vectors_comb)
proj_comb_2d.shape

# %%
en_proj_2d_ = proj_comb_2d[:len(cont_en_doc_vectors)]
de_proj_2d_ = proj_comb_2d[len(cont_en_doc_vectors):-1]
query_proj_2d_ = [proj_comb_2d[-1]]

print(len(cont_en_doc_vectors), len(cont_de_doc_vectors), len(query_vector))
print(len(en_proj_2d_), len(de_proj_2d_), len(query_proj_2d_))

# %%
ret_colors = []
ret_docs = []
ret_projs = []

proj_2d = en_proj_2d_
indices = retrieved['en_ind']
docs = scraped_en_docs


for i in range(len(proj_2d)):
    if i not in indices:
        continue
    elif i in indices[:10]:
        ret_colors.append('red')
        ret_docs.append(docs[i])
        ret_projs.append(proj_2d[i])
    elif i in indices[90:]:
        ret_colors.append('blue')
        ret_docs.append(docs[i])
        ret_projs.append(proj_2d[i])  
        
        
proj_2d = de_proj_2d_
indices = retrieved['de_ind']
docs = scraped_de_docs


for i in range(len(proj_2d)):
    if i not in indices:
        continue
    elif i in indices[:10]:
        ret_colors.append('red')
        ret_docs.append(docs[i])
        ret_projs.append(proj_2d[i])
    else:
        ret_colors.append('blue')
        ret_docs.append(docs[i])
        ret_projs.append(proj_2d[i])

# %%
ret_docs.append(query)
ret_colors.append('green')
ret_projs.extend(query_proj_2d_)

# %%
projection.plot_umap_2d(ret_docs, ret_projs, ret_colors)

# %%
def plot_umap_for_n(n):
    ret_colors = []
    ret_docs = []
    ret_projs = []
    
    proj_2d = en_proj_2d_
    indices = retrieved['en_ind']
    docs = scraped_en_docs
    
    
    for i in range(len(proj_2d)):
        if i not in indices:
            continue
        elif i in indices[:n]:
            ret_colors.append('red')
            ret_docs.append(docs[i])
            ret_projs.append(proj_2d[i])
        elif i in indices[100-n:]:
            ret_colors.append('blue')
            ret_docs.append(docs[i])
            ret_projs.append(proj_2d[i])  
            
            
    proj_2d = de_proj_2d_
    indices = retrieved['de_ind']
    docs = scraped_de_docs
    
    
    for i in range(len(proj_2d)):
        if i not in indices:
            continue
        elif i in indices[:n]:
            ret_colors.append('red')
            ret_docs.append(docs[i])
            ret_projs.append(proj_2d[i])
        else:
            ret_colors.append('blue')
            ret_docs.append(docs[i])
            ret_projs.append(proj_2d[i])  
            
    ret_docs.append(query)
    ret_colors.append('green')
    ret_projs.extend(query_proj_2d_)
    
    projection.plot_umap_2d(ret_docs, ret_projs, ret_colors)

# %%
plot_umap_for_n(5)

# %%
plot_umap_for_n(10)

# %%
plot_umap_for_n(20)

# %%
plot_umap_for_n(20)

# %%
plot_umap_for_n(30)

# %%
plot_umap_for_n(40)

# %%
for doc in retrieved['en_docs'][:5]:
    print(doc)

# %%
retrieved['en_docs'][:5]

# %%
import spacy
nlp_en = spacy.load("en_core_web_sm")
nlp_de = spacy.load('de_core_news_sm')

# %%
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
# define stop words for EN and DE
stop_words_en = set(stopwords.words('english'))
stop_words_de = set(stopwords.words('german'))

# %%
for doc in retrieved['en_docs'][:5]:
    noun_chunks = [nc for nc in nlp_en(doc).noun_chunks]
    for nc in noun_chunks:
        nc = str(nc)
        nc = nc.lower()
        ncs = [re.sub(stop, "", nc) for stop in stop_words_en]
        print(ncs)

# %%
for doc in retrieved['de_docs'][:5]:
    noun_chunks = [nc for nc in nlp_de(doc).noun_chunks]
    print(noun_chunks)

# %%
# function similar to the one under utils/explain.py
import re

TOKENS = 0
NOUN_CHUNKS = 1

def get_token_import_doc(encoding, query_vec, doc, lang=None, which_type=TOKENS): 
    if which_type == TOKENS:
        tokens = tokenize.get_tokens(doc, lang)
        # tokens = tokenize.get_naive_tokens(doc)
    elif which_type == NOUN_CHUNKS:
        nlp = nlp_en if lang == 'en' else nlp_de
        tokens = [nc for nc in nlp(doc).noun_chunks]
    
    tok_imp = {}
    for tok in tokens:
        doc_wo_tok = re.sub(str(tok), '', doc.lower())
        
        sent_with_tok_vec = encoding.encode(sent=[doc], lang=lang)
        sent_wo_tok_vec = encoding.encode(sent=[doc_wo_tok], lang=lang)
        
        retrieval = vectorize.Retrieval(vectors=[sent_with_tok_vec, sent_wo_tok_vec],
                                docs=[[doc], [doc_wo_tok]]
                               )
        ret = retrieval.retrieve(query_vec=query_vec, num_ret=len(doc))
        ref = ret['en_sim'][0]
        sim = ret['de_sim'][0]        
        imp = (ref-sim)/ref
        
        if imp != 0:
            tok_imp[tok] = imp 
            
    tokens_import = dict(sorted(tok_imp.items(), key=lambda item: item[1]))
    
    return tokens_import

# %%
for ind in range(2):
    doc = retrieved['en_docs'][ind]
    sim = retrieved['en_sim'][ind]
    print(doc, sim)
    print(get_token_import_doc(encoding=encoding, query_vec=query_vector, doc=doc, lang='en', which_type=TOKENS))
    print(get_token_import_doc(encoding=encoding, query_vec=query_vector, doc=doc, lang='en', which_type=NOUN_CHUNKS))
    print("----")

# %%
def display_tok_imp(tok_imp):
    for val in tok_imp:
        print(val, tok_imp[val])

# %%
ind_1, ind_2 = 0, 80

print(f"Document {ind_1}")
doc = retrieved['en_docs'][ind_1]
sim = retrieved['en_sim'][ind_1]
print(doc, sim)
display_tok_imp(get_token_import_doc(encoding=encoding, query_vec=query_vector, doc=doc, lang='en', which_type=TOKENS))
print("----")
display_tok_imp(get_token_import_doc(encoding=encoding, query_vec=query_vector, doc=doc, lang='en', which_type=NOUN_CHUNKS))
print("----")
print("----")

print(f"Document {ind_2}")
doc = retrieved['en_docs'][ind_2]
sim = retrieved['en_sim'][ind_2]
print(doc, sim)
display_tok_imp(get_token_import_doc(encoding=encoding, query_vec=query_vector, doc=doc, lang='en', which_type=TOKENS))
print("----")
display_tok_imp(get_token_import_doc(encoding=encoding, query_vec=query_vector, doc=doc, lang='en', which_type=NOUN_CHUNKS))
print("----")
print("----")

print(f"Document {ind_1} + {ind_2}")
doc = retrieved['en_docs'][ind_1] + "\n" + retrieved['en_docs'][ind_2]
display_tok_imp(get_token_import_doc(encoding=encoding, query_vec=query_vector, doc=doc, lang='en', which_type=TOKENS))
print("----")
display_tok_imp(get_token_import_doc(encoding=encoding, query_vec=query_vector, doc=doc, lang='en', which_type=NOUN_CHUNKS))
print("----")
print("----")

# %%
doc = retrieved['en_docs'][5]
new_doc = re.sub("the main factors", "--", doc)

# %%
doc_vec = encoding.encode([doc])
new_doc_vec = encoding.encode([new_doc])

# %%
from sklearn.metrics.pairwise import cosine_similarity
cosine_similarity(query_vector, Y=doc_vec, 
                           dense_output=True)[0]

# %%
cosine_similarity(query_vector, Y=new_doc_vec, 
                           dense_output=True)[0]

# %% [markdown]
# ## Intra-similarity

# %%
from imp import reload
reload(vectorize)

# %%
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np

# %%
def sort_dict(dict_to_sort):
    return dict(sorted(dict_to_sort.items(), key=lambda item: item[1]))

# %%
def get_imp_word(query):
    query_vec = encoding.encode(sent=[query])
    word_import = {}
    for word in query.split(" "):
        word_vec = encoding.encode(sent=[word])
        word_import[word] = cosine_similarity(word_vec, query_vec)[0]
    word_import = sort_dict(word_import)
    imp_word = list(word_import.keys())[-1]
    return imp_word

# %%
# query = 'Collision avoidance system'
query = 'adaptive cruise control'

imp_word = get_imp_word(query)

# %%
from transformers import BertTokenizer
import torch
tokenizer = BertTokenizer.from_pretrained('bert-base-multilingual-uncased')
cont_model = torch.load('/home/sudhi/thesis/thesis_cltr_app/data/models/model_MLM_NSP.pt').module.eval()

# %%
word_vec = encoding.encode(sent=[imp_word])
np.asarray(word_vec).shape

# %%
docs_with_word_idx = [idx for idx, doc in enumerate(scraped_en_docs) if imp_word in doc][:100]
docs_with_word = [scraped_en_docs[idx] for idx in docs_with_word_idx]

# %%
docs_with_word_vec = encoding.encode(docs_with_word)
total_len = len(docs_with_word_vec)

# %%
np.asarray(docs_with_word_vec).shape

# %%
sim = cosine_similarity(word_vec, Y=docs_with_word_vec, 
                           dense_output=True)[0]

# %%
ind = np.argsort(sim)[-10:][::-1]
[docs_with_word[idx] for idx in ind]

# %%
ind = np.argsort(sim)[:10]
idxs = [docs_with_word_idx[idx] for idx in ind]
[scraped_en_docs[idx] for idx in idxs]

# %%
retrieved

# %%
query_vector = encoding.encode(sent=[query])
retrieved = cont_retrieval.retrieve(query_vec=query_vector, num_ret=100)

# %%
import re

# %%
query_proj_2d = projection.get_projection_2d(query_vector)

# %%
def plot_umap_intra_sim(retrieved, imp_word):
    def strip_text(doc, word):
        sp = doc.split(" ")
        index = [idx for idx, s in enumerate(sp) if word in s][0]
        return " ".join(doc.split(" ")[index-20:index+20])
            
    ret_colors = []
    ret_docs = []
    ret_projs = []
    
    proj_2d = en_proj_2d
    indices = retrieved['en_ind']
    docs = scraped_en_docs
    
    for i in range(len(proj_2d)):
        if i in indices[:10]:
            ret_colors.append('red')
            ret_docs.append(docs[i])
            ret_projs.append(proj_2d[i])
        elif i in idxs:
            ret_colors.append('blue')
            stripped_doc = strip_text(docs[i], imp_word)
            ret_docs.append(stripped_doc)
            # ret_docs.append(docs[i])
            ret_projs.append(proj_2d[i])  
            
    ret_docs.append(query)
    ret_colors.append('green')
    ret_projs.extend(query_proj_2d)
    
    projection.plot_umap_2d(ret_docs, ret_projs, ret_colors)

# %%
plot_umap_intra_sim(retrieved, imp_word)

# %% [markdown]
# ## MLM for query expansion

# %%
from transformers import BertTokenizer
import torch
tokenizer = BertTokenizer.from_pretrained('bert-base-multilingual-uncased')
cont_model = torch.load('/home/sudhi/thesis/thesis_cltr_app/data/models/model_MLM_NSP.pt').module.eval()

# %%
def retrieve(query):
    query_vector = encoding.encode(sent=[query])
    retrieved = cont_retrieval.retrieve(query_vec=query_vector, num_ret=100)
    
    en_preds = vectorize.get_preds(cont_model, query, retrieved['en_docs'])
    en_ret_docs = vectorize.get_top_k(en_preds, retrieved['en_docs'], 10)
    
    de_preds = vectorize.get_preds(cont_model.to('cuda:0'), query, retrieved['de_docs'])
    de_ret_docs = vectorize.get_top_k(en_preds, retrieved['de_docs'], 10)    
    
    return en_ret_docs, de_ret_docs

# %%
query = 'adaptive crusie control'
query_vector = encoding.encode(sent=[query])
retrieved = cont_retrieval.retrieve(query_vec=query_vector, num_ret=100)

# %%
len(retrieved['en_docs'])

# %%
en_preds = vectorize.get_preds(cont_model, query, retrieved['en_docs'])
en_ret_docs = vectorize.get_top_k(en_preds, retrieved['en_docs'], 10)

# %%
de_preds = vectorize.get_preds(cont_model.to('cuda:0'), query, retrieved['de_docs'])
de_ret_docs = vectorize.get_top_k(en_preds, retrieved['de_docs'], 100)

# %%
en_ret_docs

# %%
de_ret_docs

# %%
from tqdm import tqdm
def get_preds(model, query, doc):
    preds = []
    with torch.no_grad():
        inputs = tokenizer(query, doc, return_tensors='pt',
                      max_length=512, padding=True, truncation=True).to('cuda')
        output = model(**inputs, output_hidden_states=True, output_attentions=True)

    return output

# %%
def mean_pooling(sent):
    with torch.no_grad():
        inputs = tokenizer(sent, return_tensors='pt',
                      max_length=512, padding=True, truncation=True).to('cuda')
        output = cont_model(**inputs, output_hidden_states=True, output_attentions=True)
    
    # last layer gives the best embeddings
    token_embeddings = output['hidden_states'][-1] 
    # Mean Pooling - Take attention mask into account for correct averaging
    input_mask_expanded = inputs['attention_mask'].unsqueeze(-1).expand(token_embeddings.size()).float()
    sent_embedding = torch.sum(token_embeddings * input_mask_expanded, 1) / torch.clamp(input_mask_expanded.sum(1), min=1e-9)
    return sent_embedding.cpu()

# %%
inputs.keys()

# %%
mean_pooling(output, inputs['attention_mask'])[0]

# %%
input_id_list = inputs['input_ids'][0].tolist() # Batch index 0
print(input_id_list)
tokens = tokenizer.convert_ids_to_tokens(input_id_list)  
print(tokens)
print(len(tokens))

# %%
output.attentions[11].size()

# %%
query_tokens = tokens[tokens.index('[CLS]')+1: tokens.index('[SEP]')]

# %%
import numpy as np
head = 11
num_heads = 12
for head in range(num_heads):
    print(f"Head {head}")
    for ind, token in enumerate(tokens):
        attention = output.attentions[11][0][head][ind]
        indices = np.argsort(attention.cpu().numpy())[::-1][:5]
        print(f"{token}  --> {' '.join([tokens[idx] for idx in indices])}")
    print()

# %%
from transformers import pipeline
unmasker = pipeline('fill-mask', model=cont_model.to('cpu'), tokenizer=tokenizer, top_k=10)
from nltk.corpus import stopwords
stop_words_en = set(stopwords.words('english'))
stop_words_de = set(stopwords.words('german'))
import string
punct = list(string.punctuation)
def get_suggestions(query, imp_word):
    masked_query = re.sub(imp_word, "[MASK]", query)
    preds = unmasker(masked_query)
    suggestions = []
    for pred in preds:
        token_str = re.sub(" ", "", pred['token_str'])
        if token_str in stop_words_en:
            continue
        if token_str in stop_words_de:
            continue
        if token_str in punct:
            continue
        # TODO: sometimes, comprising, inclusing, etc. comes
        # add a rule to avoid these
        # avoid numbers
        suggestion = pred['sequence']
        if suggestion.lower() != query.lower():
            suggestions.append(suggestion)
    return suggestions

# %%
query = "sensors and cars"
imp_word = get_imp_word(query)
get_suggestions(query, imp_word)

# %%
np.argsort(np.asarray([5, 4, 1, 10]))[::-1]

# %% [markdown]
# ## Retrieving with the contextual model

# %%
from transformers import BertTokenizer
import torch
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np
tokenizer = BertTokenizer.from_pretrained('bert-base-multilingual-uncased')
cont_model = torch.load('/home/sudhi/thesis/thesis_cltr_app/data/models/model_MLM_NSP.pt').module.eval()

# %%
import sys
sys.path.append('../')
from util import util, corpus, alignment, vectorize, retrieval, tokenize

from tqdm.notebook import tqdm as tq
import pandas as pd

# %%
scraped_en_docs = util.decompress_pickle('/home/sudhi/thesis/thesis_cltr_app/data/docs/scraped_en_docs') 
scraped_de_docs = util.decompress_pickle('/home/sudhi/thesis/thesis_cltr_app/data/docs/scraped_de_docs')          

# static model
st_en_doc_vectors = util.decompress_pickle('/home/sudhi/thesis/thesis_cltr_app/data/static/st_en_doc_vectors')
st_de_doc_vectors = util.decompress_pickle('/home/sudhi/thesis/thesis_cltr_app/data/static/st_de_doc_vectors')

scraped_en_docs_, st_en_doc_vectors_ = [], []
for doc, vec in zip(scraped_en_docs, st_en_doc_vectors):
    if len(doc.split(' ')) < 10:
        continue
    scraped_en_docs_.append(doc)
    st_en_doc_vectors_.append(vec)
        
scraped_de_docs_, st_de_doc_vectors_ = [], []
for doc, vec in zip(scraped_de_docs, st_de_doc_vectors):
    if len(doc.split(' ')) < 10:
        continue
    scraped_de_docs_.append(doc)
    st_de_doc_vectors_.append(vec)    
        
en_wv_unsup = util.decompress_pickle('/home/sudhi/thesis/thesis_cltr_app/data/static/en_wv_unsup')
de_wv_unsup = util.decompress_pickle('/home/sudhi/thesis/thesis_cltr_app/data/static/de_wv_unsup')

st_encoding = vectorize.Encoding(model=[en_wv_unsup, de_wv_unsup], model_type='static')
st_retrieval = vectorize.Retrieval(vectors=[st_en_doc_vectors_, st_de_doc_vectors_],
                                docs=[scraped_en_docs_, scraped_de_docs_]
                               )

# %%
query = 'adaptive cruise control'
query_vector = st_encoding.encode(sent=[query], lang='en')
retrieved = st_retrieval.retrieve(query_vec=query_vector, num_ret=100)
docs = [retrieved['en_docs'], retrieved['de_docs']]

# %%
en_preds = vectorize.get_preds(cont_model, query, retrieved['en_docs'])
en_ret_docs = vectorize.get_top_k(en_preds, retrieved['en_docs'], 100)
# Out:
# 100%|██████████| 100/100 [00:01<00:00, 89.24it/s]

# %%
de_preds = vectorize.get_preds(cont_model.to('cuda:0'), query, retrieved['de_docs'])
de_ret_docs = vectorize.get_top_k(en_preds, retrieved['de_docs'], 100)
# Out:
# 100%|██████████| 100/100 [00:01<00:00, 85.50it/s]

# %% [markdown]
# **trying to understand why the 500 documents retrieved by the static model are reranked by the contextual model.**

# %%
re_ranking = {}
for ct_ind, doc in enumerate(en_ret_docs):
    re_ranking[ct_ind] = retrieved['en_docs'].index(doc)

# %%
re_ranking
# Out:
# {0: 34,
#  1: 66,
#  2: 50,
#  3: 65,
#  4: 3,
#  5: 0,
#  6: 36,
#  7: 33,
#  8: 6,
#  9: 41,
#  10: 77,
#  11: 16,
#  12: 24,
#  13: 79,
#  14: 73,
#  15: 52,
#  16: 32,
#  17: 31,
#  18: 21,
#  19: 7,
#  20: 78,
#  21: 54,
#  22: 1,
#  23: 64,
#  24: 8,
#  25: 90,
#  26: 19,
#  27: 59,
#  28: 11,
#  29: 30,
#  30: 17,
#  31: 14,
#  32: 15,
#  33: 74,
#  34: 48,
#  35: 35,
#  36: 70,
#  37: 2,
#  38: 40,
#  39: 68,
#  40: 84,
#  41: 62,
#  42: 20,
#  43: 38,
#  44: 18,
#  45: 47,
#  46: 37,
#  47: 49,
#  48: 44,
#  49: 86,
#  50: 5,
#  51: 51,
#  52: 98,
#  53: 57,
#  54: 9,
#  55: 43,
#  56: 91,
#  57: 55,
#  58: 61,
#  59: 75,
#  60: 26,
#  61: 45,
#  62: 25,
#  63: 13,
#  64: 28,
#  65: 72,
#  66: 85,
#  67: 87,
#  68: 12,
#  69: 23,
#  70: 60,
#  71: 99,
#  72: 53,
#  73: 56,
#  74: 27,
#  75: 94,
#  76: 29,
#  77: 93,
#  78: 71,
#  79: 89,
#  80: 82,
#  81: 80,
#  82: 92,
#  83: 81,
#  84: 97,
#  85: 42,
#  86: 4,
#  87: 22,
#  88: 46,
#  89: 95,
#  90: 69,
#  91: 10,
#  92: 63,
#  93: 96,
#  94: 76,
#  95: 83,
#  96: 67,
#  97: 58,
#  98: 39,
#  99: 88}

# %%
for ind in range(100):
    print(f"{ind}\nSTATIC:{retrieved['en_docs'][ind]}\nCONT:{en_ret_docs[ind]}")
# Out:
# 0
# STATIC:The adaptive cruise control adapts the vehicle’s speed to the flow of traffic.
# CONT:Adaptive cruise control makes riding more convenient for the rider, especially in dense traffic, and could help to prevent rear-end collisions.
# 1
# STATIC:An ideal upgrade for the adaptive cruise assist is also the
# CONT:The adaptive cruise assist maintains proper speed and following distance via targeted acceleration and braking. The car automatically adapts its speed to the traffic situation and the route, for example at curves and cross-ways. In stop-and-go traffic as well as traffic jam situations, the ACA can bring the car to a complete stop. Depending on the duration of the stop, the car can start automatically again.
# 2
# STATIC:Traffic jam assist is a subsystem of adaptive cruise control (ACC) or adaptive cruise assist (ACA). In vehicles with an automatic transmission, traffic jam assist can assume certain steering tasks over a speed range up to 65 km/h
# CONT:The adaptive cruise assist, which customers know from many of the full-size models, assists with longitudinal and lateral guidance. It maintains the speed and distance to the vehicle in front and assists with lane guidance by means of gentle interventions in the electromechanical steering. This increases the level of ride comfort during long journeys in particular.
# 3
# STATIC:The adaptive cruise control (ACC) helps to adapt the speed in heavy traffic to the flow to keep a safe distance to the preceding vehicle.
# CONT:When the adaptive cruise assist system (optional) is activated, the predictive efficiency assist becomes active not only during deceleration but also during acceleration. If it is switched off, it provides the driver with prompts that indicate when it would be sensible to take their foot off the right-hand pedal: The driver feels an impulse in the active accelerator pedal and sees information displayed on the head-up display (optional) and the Audi virtual cockpit (standard).
# 4
# STATIC:Safety equipment includes forward-collision warning, lane-departure warning, blind-sport warning and, for the first time in an Aston Martin, adaptive cruise control and lane keep assist.
# CONT:The adaptive cruise control (ACC) helps to adapt the speed in heavy traffic to the flow to keep a safe distance to the preceding vehicle.
# 5
# STATIC:Customers can pay more for adaptive cruise control, blind-spot information and cross-traffic alert.
# CONT:The adaptive cruise control adapts the vehicle’s speed to the flow of traffic.
# 6
# STATIC:The adaptive cruise assist, which combines the functions of adaptive speed assist, traffic jam assist and active lane assist, reduces the driver’s workload – particularly on long journeys. In combination with
# CONT:The adaptive cruise control also uses the radar sensor to keep the A1 citycarver at the distance to the vehicle in front selected by the driver. In cooperation with the manual transmission, the system operates in the speed range between 30 km/h
# 7
# STATIC:(standard) is active, the adaptive cruise assist decelerates and accelerates the Audi
# CONT:The adaptive cruise assist (ACA) assists the driver with longitudinal and lateral control over the entire speed range – substantially enhancing comfort on long journeys, in particular. It incorporates the functions of adaptive cruise control, traffic jam assist and active lane assist. Depending on the model, the ACA uses the radar sensor in the nose of the vehicle, the laser scanner, the front camera and the ultrasonic sensors to permanently monitor the vehicle’s surroundings.
# 8
# STATIC:The ACC system behaves as a conventional cruise control system in an open lane condition.
# CONT:The adaptive cruise assist, which combines the functions of adaptive speed assist, traffic jam assist and active lane assist, reduces the driver’s workload – particularly on long journeys. In combination with
# 9
# STATIC:Efficiency assist helps the driver to drive preemptively and save fuel. The system works closely together with adaptive cruise control (ACC) or adaptive cruise assist (ACA). It accesses predictive route data from navigation and Car-to-X information. In order to detect traffic signs and other vehicles, the efficiency assist uses the front camera as well as data from the front and rear-facing radar sensors.
# CONT:The adaptive cruise control is also radar-based. It keeps the Audi A1 Sportback at the desired distance from the vehicle ahead. The driver can set the distance in five steps and adjust acceleration using the modes in
# 10
# STATIC:In May, ZF and Intel's Mobileye unit said they will jointly develop advanced safety systems -- including automatic emergency braking, adaptive cruise control and lane keeping systems -- for Toyota.
# CONT:The adaptive cruise assist, which can help the driver in many situations with accelerating, decelerating, and steering within the lane, is a new addition to the optional systems. In order to maintain lateral guidance, the driver only needs to touch the capacitive steering wheel gently, which is part of the system, to prove that they are paying attention. In combination with the camera-based traffic sign recognition, the adaptive cruise assist ensures that the car decelerates in certain situations, for example when approaching speed limits and town signs. As soon as the restricted area ends, it accelerates the SQ2
# 11
# STATIC:automatically controls the speed of the truck and the distance to the traffic ahead. The system keeps a speed set by the driver constant or adjusts it to the changing traffic conditions by automatic acceleration or braking. In traffic jams or slow traffic, the adaptive cruise control brakes the vehicle to a standstill.
# CONT:Adaptive cruise control (ACC) offers relief to drivers especially on long trips and in stop-and-go traffic. It maintains a preset distance to the vehicle ahead by automatically accelerating and braking. The driver can choose from five distance levels and adjust acceleration and control system dynamics with Audi drive select.
# 12
# STATIC:And the driver assistant systems in the new S models** also provide a host of convenient features. In the S6 Sedan**, S6 Avant** and S7 Sportback**, adaptive cruise assist (ACA) stands out from the extensive range—with its subfunctions, it helps with longitudinal and lateral control from standstill to top speed. In conjunction with the standard efficiency assistant, the ACA can accelerate and decelerate the large Avant independently. In the SQ5 TDI**, longitudinal and lateral control are allocated to the adaptive cruise control and Audi active lane assist.
# CONT:The adaptive cruise assist, which combines the functions of adaptive speed assist, traffic jam assist and active lane assist, reduces the driver’s workload – particularly on long journeys. In combination with efficiency assist it brakes and accelerates the Audi Q7 in anticipation of the conditions ahead. The emergency assist is also new: If the driver is inactive, the system brings the car to a stop and initiates protective and rescue measures. This function is active in assisted and manual modes.
# 13
# STATIC:. This increases the level of comfort on long-distance journeys in particular. To do this, it integrates the functions of the adaptive cruise control and the Audi active lane assist. A lane assist function for bottlenecks and congestion situation are also integrated. Behind the assistance systems is the
# CONT:From adaptive cruise control through the quattro drive to the Audi virtual cockpit: The technology lexicon contains details on all Audi technologies, in compact form and all in one place. Here we provide background information on the individual systems and explain the benefits to the customer.
# 14
# STATIC:the radar-based longitudinal guidance of adaptive cruise control (ACC) stop & go with the video-based lateral guidance of lane centering assist in one system.
# CONT:When the adaptive cruise control (ACC) is active, the PEA assists the driver not only with decelerating but also with fuel-efficient acceleration. If the ACC is switched off, the driver receives prompts that indicate when it would be sensible to take their foot off the right-hand pedal. The driver feels an impulse in the active accelerator pedal and sees information displayed in the Audi virtual cockpit (standard) and on the head-up display (optional). Detailed symbols, e.g. for intersections, town signs and traffic driving in front, explain the reason for the reduction in speed.
# 15
# STATIC:The 38 driver assistance systems that Audi provides for the new S8** are divided into the City and Tour packages. Adaptive cruise assist – the central system in the “Tour” package – stands out among the comprehensive range of assist systems. It combines the functions of adaptive cruise control, traffic jam assist and lane tracking. In conjunction with predictive
# CONT:The adaptive cruise assist takes over steering, accelerating, and decelerating for the driver in many situations. The improved restarting comfort is a new feature: Even after a longer standstill, the adaptive cruise assist gets the car start rolling again if the car in front starts moving. A capacitive steering wheel will follow later. It takes only a slight touch for the car to detect that the driver is taking responsibility for steering and automatic lateral guidance can remain active.
# 16
# STATIC:Adaptive cruise control (ACC) offers relief to drivers especially on long trips and in stop-and-go traffic. It maintains a preset distance to the vehicle ahead by automatically accelerating and braking. The driver can choose from five distance levels and adjust acceleration and control system dynamics with Audi drive select.
# CONT:The adaptive cruise control also is radar-based. It keeps the Audi A1 Sportback at the desired distance from the vehicle ahead. If the vehicle is equipped with S tronic, the system covers a speed range of 0 to 200 km/h
# 17
# STATIC:Audi bundles the most important systems in the assistance package. Along with the adaptive cruise assist, it comprises camera-based
# CONT:The supplemental efficiency assist function enables the adaptive cruise assist to predictively adjust speed to speed limits, curves and roundabouts. If route guidance is active, it can even adjust speed for turns. The driver sees the target speed on the display. In doing so, the system always adapts the driving style to the selected driving program, from efficient to sporty.
# 18
# STATIC:The function for piloted driving in traffic jams, which Audi is currently moving to production, is based on existing assistance systems such as Audi adaptive cruise control and traffic jam assist. At speeds between 0 and 65 km/h
# CONT:For the additional efficiency assistant function, the adaptive cruise assist predictively factors in speed limits, bends, roundabouts and – if route guidance is active – also turnings as part of the cruise control function. Besides the predictive information in the instrument cluster, the efficiency assistant also provides haptic feedback via the active gas pedal. Together with the MHEV system, these assistance functions can help promote fuel economy.
# 19
# STATIC:The predictive efficiency assist (PEA) adjusts the behavior of the coasting recuperation to the situation at hand. It uses the predictive route data from the navigation database and monitors the distance to the vehicle ahead using signals from the camera and radar. When the adaptive cruise control (ACC) is active, the PEA supports the driver by braking and accelerating automatically in order to further enhance efficiency and comfort.
# CONT:(standard) is active, the adaptive cruise assist decelerates and accelerates the Audi
# 20
# STATIC:Traffic Jam Assist combines a full speed range Adaptive Cruise Control system with Auto-Go capability, together with a full speed Lane Keeping Assist system.
# CONT:Adaptive cruise control (ACC), collision and blind spot assist represent a new level of safety for motorcyclists by supporting riders in critical situations and helping them to avoid accidents without compromising their riding enjoyment.
# 21
# STATIC:For the additional efficiency assistant function, the adaptive cruise assist predictively factors in speed limits, bends, roundabouts and – if route guidance is active – also turnings as part of the cruise control function. Besides the predictive information in the instrument cluster, the efficiency assistant also provides haptic feedback via the active gas pedal. Together with the MHEV system, these assistance functions can help promote fuel economy.
# CONT:When the optional adaptive cruise assist including the radar cruise control is active, the PEA assists the driver not only with decelerating but also with fuel-efficient acceleration. If it is switched off, the driver receives prompts that indicate when it would be sensible to take their foot off the right-hand pedal. The driver feels an impulse in the active accelerator pedal and sees information displayed in the Audi virtual cockpit (standard) and on the head-up display (optional). Detailed symbols, e.g. for intersections, town signs and vehicles driving in front, explain the reason for the reduction in speed.
# 22
# STATIC:accelerator-pedal position and any system requirements that can influence the engine torque, such as cruise control, or active safety systems such as the electronic stability program ESP®.
# CONT:An ideal upgrade for the adaptive cruise assist is also the
# 23
# STATIC:Our sensors and cameras provide driver assistance functions like Lane Departure Warning, Emergency Brake Assist and Adaptive Cruise Control.
# CONT:The ACC system behaves as a conventional cruise control system in an open lane condition. When approaching a slower vehicle in subject vehicle path, the ACC system uses the Powertrain and the Electronic Brake System to adjust the subject vehicle speed in order to maintain the driver selected headway. Generation 4 includes: ACC Stop&Go, Reaction on a priori static objects, Auto Go (driver confirmation is no longer required within a defined maximum time interval for drive off from standstill), External Speed Assist Input.
# 24
# STATIC:The adaptive cruise assist, which combines the functions of adaptive speed assist, traffic jam assist and active lane assist, reduces the driver’s workload – particularly on long journeys. In combination with efficiency assist it brakes and accelerates the Audi Q7 in anticipation of the conditions ahead. The emergency assist is also new: If the driver is inactive, the system brings the car to a stop and initiates protective and rescue measures. This function is active in assisted and manual modes.
# CONT:The ACC system behaves as a conventional cruise control system in an open lane condition.
# 25
# STATIC:The “Drive” package comprises multiple elements: the navigation package, the Audi virtual cockpit, the emergency assist, traffic sign recognition via camera, cruise control, and the adaptive cruise assist which is based upon it. In many situations, it can assist the driver with accelerating, decelerating, and steering within the lane.
# CONT:In order to maintain lateral guidance, the driver need only gently touch the capacitive steering wheel, which is part of the system, to prove that they are paying attention. The adaptive cruise assist operates up to a speed of 210 km/h
# 26
# STATIC:The A4 models are available with a host of driver assistance systems. The optional systems are bundled into the “Tour,” “City” and “Park” packages. An important system in the “Tour” package is the adaptive cruise control including stop & go function for automatic distance control. In conjunction with the predictive
# CONT:The predictive efficiency assist (PEA) adjusts the behavior of the coasting recuperation to the situation at hand. It uses the predictive route data from the navigation database and monitors the distance to the vehicle ahead using signals from the camera and radar. When the adaptive cruise control (ACC) is active, the PEA supports the driver by braking and accelerating automatically in order to further enhance efficiency and comfort.
# 27
# STATIC:incorporates all of the assistance systems from the Q5. The turn assist, collision avoidance assist, and exit warning help improve safety. The adaptive cruise assist can take over accelerating, decelerating and keeping in lane for drivers over long distances. The predictive efficiency assist helps them maintain a predictive driving style with the goal of lowering fuel consumption.
# CONT:Those wishing to drive particularly efficiently can supplement the ACA with predictive control and the efficiency assist. This enables an anticipatory driving style. To detect the traffic situation and the course of the route, the ACA analyzes camera images – including images of traffic signs – plus the navigation data. If the adaptive cruise assist is deactivated, the
# 28
# STATIC:The A4 models are available with a host of driver assist systems. The optional systems are bundled into the “Tour”, “City” and “Park” packages. An important system in the “Tour” package is the adaptive cruise control including Stop&Go function for automatic distance control. In conjunction with the predictive
# CONT:automatically controls the speed of the truck and the distance to the traffic ahead. The system keeps a speed set by the driver constant or adjusts it to the changing traffic conditions by automatic acceleration or braking. In traffic jams or slow traffic, the adaptive cruise control brakes the vehicle to a standstill.
# 29
# STATIC:dynamic handling system as an option. With it, drivers can select from four modes that influence the driving characteristics: Auto, dynamic, efficiency and individual. In the base configuration, Audi drive select affects the power steering and the engine characteristic. Optional components, such as the S tronic, adaptive cruise control with Stop&Go function, cruise control, start-stop system, engine sound and sport suspension with adjustable dampers are connected to the dynamic handling system.
# CONT:If the cruise assist is switched on or the ACC is activated, efficiency assist regulates actively. It decelerates and accelerates predictively and adapts the speed to the course of the road and the traffic situation, also taking vehicles driving in front into account. If the driver so wishes, the system controls the freewheeling and coasting operation of the engine in cooperation with other control units. The predictive system always maintains a driving style that reflects the driving program selected – from efficient to sporty – and uses scope for recuperation in the Audi
# 30
# STATIC:If the cruise assist is switched on or the ACC is activated, efficiency assist regulates actively. It decelerates and accelerates predictively and adapts the speed to the course of the road and the traffic situation, also taking vehicles driving in front into account. If the driver so wishes, the system controls the freewheeling and coasting operation of the engine in cooperation with other control units. The predictive system always maintains a driving style that reflects the driving program selected – from efficient to sporty – and uses scope for recuperation in the Audi
# CONT:Audi bundles the most important systems in the assistance package. Along with the adaptive cruise assist, it comprises camera-based
# 31
# STATIC:The supplemental efficiency assist function enables the adaptive cruise assist to predictively adjust speed to speed limits, curves and roundabouts. If route guidance is active, it can even adjust speed for turns. The driver sees the target speed on the display. In doing so, the system always adapts the driving style to the selected driving program, from efficient to sporty.
# CONT:the radar-based longitudinal guidance of adaptive cruise control (ACC) stop & go with the video-based lateral guidance of lane centering assist in one system.
# 32
# STATIC:The adaptive cruise control also is radar-based. It keeps the Audi A1 Sportback at the desired distance from the vehicle ahead. If the vehicle is equipped with S tronic, the system covers a speed range of 0 to 200 km/h
# CONT:The 38 driver assistance systems that Audi provides for the new S8** are divided into the City and Tour packages. Adaptive cruise assist – the central system in the “Tour” package – stands out among the comprehensive range of assist systems. It combines the functions of adaptive cruise control, traffic jam assist and lane tracking. In conjunction with predictive
# 33
# STATIC:The adaptive cruise assist (ACA) assists the driver with longitudinal and lateral control over the entire speed range – substantially enhancing comfort on long journeys, in particular. It incorporates the functions of adaptive cruise control, traffic jam assist and active lane assist. Depending on the model, the ACA uses the radar sensor in the nose of the vehicle, the laser scanner, the front camera and the ultrasonic sensors to permanently monitor the vehicle’s surroundings.
# CONT:A radar sensor is usually at the core of the adaptive cruise control (ACC). Installed at the front of the vehicle, the system permanently monitors the road ahead. As long as the road ahead is clear, ACC maintains the speed set by the driver. If the system spots a slower vehicle within its detection range, it gently reduces speed by releasing the accelerator or actively engaging the brake control system. If the vehicle ahead speeds up or changes lanes, the ACC automatically accelerates to the driver’s desired speed.
# 34
# STATIC:Adaptive cruise control makes riding more convenient for the rider, especially in dense traffic, and could help to prevent rear-end collisions.
# CONT:The 38 driver assistance systems that Audi provides for the new S8** are divided into the City and Tour packages. Adaptive cruise assist – the central system in the “Tour” package – stands out among the comprehensive range of assist systems. It combines the functions of adaptive cruise control, traffic jam assist and lane tracking. In conjunction with predictive efficiency assist, adaptive cruise assist brakes and accelerates the Audi S8** in anticipation of the conditions ahead. In the City assist package, Audi pre sense side joins the systems pre sense front and pre sense rear to create Audi pre sense 360°. If the system detects an impending side impact, it can operate together with the predictive active suspension to instantly raise the body by as much as 80 millimeters
# 35
# STATIC:The predictive efficiency assistant adjusts coasting recuperation behavior to the driving situation at hand. It uses the predictable route data from the navigation database and monitors the distance to the vehicle ahead using signals from the camera and radar. Depending on the situation, the system chooses predictively between freewheeling with the engine switched off and coasting recuperation, i.e. the recovery of kinetic energy and its conversion into electrical energy. When the adaptive cruise control (ACC) is active, the PEA supports the driver by automatically braking and accelerating with the aim of enhancing efficiency and comfort.
# CONT:The predictive efficiency assistant adjusts coasting recuperation behavior to the driving situation at hand. It uses the predictable route data from the navigation database and monitors the distance to the vehicle ahead using signals from the camera and radar. Depending on the situation, the system chooses predictively between freewheeling with the engine switched off and coasting recuperation, i.e. the recovery of kinetic energy and its conversion into electrical energy. When the adaptive cruise control (ACC) is active, the PEA supports the driver by automatically braking and accelerating with the aim of enhancing efficiency and comfort.
# 36
# STATIC:The adaptive cruise control also uses the radar sensor to keep the A1 citycarver at the distance to the vehicle in front selected by the driver. In cooperation with the manual transmission, the system operates in the speed range between 30 km/h
# CONT:Cruise control maintains a desired driving speed constantly starting at around 30 km/h
# 37
# STATIC:is a highlight among the optional systems. It combines the functions of adaptive cruise control, traffic jam assist, and active lane assist, including control to the middle of the lane, and is active up to a speed of 200 km/h
# CONT:Traffic jam assist is a subsystem of adaptive cruise control (ACC) or adaptive cruise assist (ACA). In vehicles with an automatic transmission, traffic jam assist can assume certain steering tasks over a speed range up to 65 km/h
# 38
# STATIC:In the new Audi A6, a large number of assist systems make driving even safer, more convenient and more relaxing. The standard Audi pre sense front system helps avoid collisions with other vehicles, pedestrians, and cyclists. Another highlight is the adaptive cruise assist, which enhances the adaptive cruise control with a lane guidance function over the entire speed range and with the traffic jam assist. An ideal upgrade for it is the efficiency assist. This brakes and accelerates the vehicle predictively by analyzing Car-to-X information, sensor information and navigation data as well as traffic signs
# CONT:Driving in heavy traffic or keeping a safe distance to the preceding vehicle calls for a high level of concentration. The adaptive cruise control (ACC) can reduce stress for the driver by automatically controlling vehicle speed and maintaining a predefined minimum distance to the preceding vehicle. As a consequence, the driver enjoys more comfort and can better concentrate on the traffic.
# 39
# STATIC:A range of driver assist technology will be available, including standard emergency braking, driver alert, adjustable speed limiting, cruise control and lane-keeping.
# CONT:The Audi Q5 Sportback is equipped with numerous driver assist systems. The adaptive cruise assist can take over accelerating, decelerating and keeping in lane for the driver in many situations. The driver only has to touch the capacitive steering wheel to maintain lateral guidance. A second high-tech system is the predictive efficiency assist, which supports a predictive driving style. The turn assist, the swerve assist, the cross-traffic assist and exit warning systems also enhance safety. The standard Audi pre sense city system helps to avoid or mitigate the consequences of collisions with road users in front of the car.
# 40
# STATIC:Driving in heavy traffic or keeping a safe distance to the preceding vehicle calls for a high level of concentration. The adaptive cruise control (ACC) can reduce stress for the driver by automatically controlling vehicle speed and maintaining a predefined minimum distance to the preceding vehicle. As a consequence, the driver enjoys more comfort and can better concentrate on the traffic.
# CONT:The technology in driver assistance systems potentially offers additional significant reductions in the number of accidents and traffic jams. Adaptive cruise control systems, for example, improve the traffic flow and make a major contribution to avoiding accidents.
# 41
# STATIC:The adaptive cruise control is also radar-based. It keeps the Audi A1 Sportback at the desired distance from the vehicle ahead. The driver can set the distance in five steps and adjust acceleration using the modes in
# CONT:models, when cruising up to a red traffic light, will make increased used of braking energy in order to charge their batteries. Coupled with predictive adaptive cruise control (pACC), the cars could even brake automatically at red lights.
# 42
# STATIC:The path to automated driving will appear familiar to many: today a customer can configure their desired car such that on the one hand it has today’s driver assistance features (e.g. lane keeping assistant, adaptive cruise control with emergency braking, and highway driving assistant) for driving on the highway. On the other hand, they can decide to go without all the parking assistance systems that support the driver during maneuvering. In the future customers will still have this freedom of choice.
# CONT:Traffic Jam Assist combines a full speed range Adaptive Cruise Control system with Auto-Go capability, together with a full speed Lane Keeping Assist system.
# 43
# STATIC:Since the introduction of the ABS brake system in the year 1978, a steady stream of new driver assistance systems that increasingly automate road traffic has been developed. Systems such as lane departure warning, cruise control and adaptive cruise control (ACC) or the electronic stability programme (ESP) relieve the driver’s workload and make road traffic safer and more comfortable. Ever more driving tasks can gradually be taken over by automated systems. Driver assistance systems have been helping to lower the number of road traffic accidents for years. However, they cannot yet avoid them completely. In order to ensure fast help in the event of an accident, the electronic emergency call system “eCall” has been developed and will be mandatory in all new cars as of 2018. It registers accidents and automatically sends out an emergency call.
# CONT:In the new Audi A6, a large number of assist systems make driving even safer, more convenient and more relaxing. The standard Audi pre sense front system helps avoid collisions with other vehicles, pedestrians, and cyclists. Another highlight is the adaptive cruise assist, which enhances the adaptive cruise control with a lane guidance function over the entire speed range and with the traffic jam assist. An ideal upgrade for it is the efficiency assist. This brakes and accelerates the vehicle predictively by analyzing Car-to-X information, sensor information and navigation data as well as traffic signs
# 44
# STATIC:The inertial measurement unit contributes to the functionality of active and passive safety systems like the ESP® and the airbag control unit as well as to driver assistance systems like the adaptive cruise control, and improves the offset performance with an integrated microcontroller. The inertial measurement unit is available for a multitude of automotive applications as well as for future advanced driver assistance systems functions and automated driving.
# CONT:The function for piloted driving in traffic jams, which Audi is currently moving to production, is based on existing assistance systems such as Audi adaptive cruise control and traffic jam assist. At speeds between 0 and 65 km/h
# 45
# STATIC:With our third generation radar sensor a predictive Emergency Brake Assist system can be triggered. It responds by activating an automatic braking system as soon as the driver’s own vehicle comes within a dangerous distance to a preceding vehicle and the driver does not respond appropriately. As a result, it can considerably reduce stopping distance. These kinds of safety functions are already integrated into modern Adaptive Cruise Control (ACC) systems today. The Emergency Brake Assist system fulfills the new EU safety regulations for driver assistance systems in commercial vehicles.
# CONT:Many innovative driver assistance systems created to increase driving comfort originated in the development centers of German vehicle manufacturers and the supply industry. Adaptive cruise control (ACC), available on the market since 1998, actively helps the driver maintain a safe distance from the vehicle in front by either braking or accelerating. The adaptive cruise control systems currently in widespread use are in fact able to brake independently, bringing the vehicle to a standstill, and to move off again automatically after a signal from the driver. Both for passenger cars and for commercial vehicles, ACC principally has a comfort function that relieves some of the stress on the driver on the highway or in constant nose-to-tail traffic. Moreover, automatic ACC also improves road safety because it helps avoid sudden emergency braking situations that arise when the vehicle is too close to the one in front or the driver’s attention lapses.
# 46
# STATIC:mode can be used. In this mode, the electronic stabilization control switches the traction control system over to off-road mode. As an option, the hill descent control can provide support here. It constantly maintains the speed specified by the driver (up to 30 km/h
# CONT:is a highlight among the optional systems. It combines the functions of adaptive cruise control, traffic jam assist, and active lane assist, including control to the middle of the lane, and is active up to a speed of 200 km/h
# 47
# STATIC:Many innovative driver assistance systems created to increase driving comfort originated in the development centers of German vehicle manufacturers and the supply industry. Adaptive cruise control (ACC), available on the market since 1998, actively helps the driver maintain a safe distance from the vehicle in front by either braking or accelerating. The adaptive cruise control systems currently in widespread use are in fact able to brake independently, bringing the vehicle to a standstill, and to move off again automatically after a signal from the driver. Both for passenger cars and for commercial vehicles, ACC principally has a comfort function that relieves some of the stress on the driver on the highway or in constant nose-to-tail traffic. Moreover, automatic ACC also improves road safety because it helps avoid sudden emergency braking situations that arise when the vehicle is too close to the one in front or the driver’s attention lapses.
# CONT:For added comfort and greater efficiency, this speed information is shared with other systems in the car. The predictive adaptive cruise control (pACC) and the predictive efficiency assistant (PEA) use these current data from the cloud for an anticipatory driving style. In the future, these systems will observe these temporary speed limits even before they enter the camera’s field of view.
# 48
# STATIC:The 38 driver assistance systems that Audi provides for the new S8** are divided into the City and Tour packages. Adaptive cruise assist – the central system in the “Tour” package – stands out among the comprehensive range of assist systems. It combines the functions of adaptive cruise control, traffic jam assist and lane tracking. In conjunction with predictive efficiency assist, adaptive cruise assist brakes and accelerates the Audi S8** in anticipation of the conditions ahead. In the City assist package, Audi pre sense side joins the systems pre sense front and pre sense rear to create Audi pre sense 360°. If the system detects an impending side impact, it can operate together with the predictive active suspension to instantly raise the body by as much as 80 millimeters
# CONT:The inertial measurement unit contributes to the functionality of active and passive safety systems like the ESP® and the airbag control unit as well as to driver assistance systems like the adaptive cruise control, and improves the offset performance with an integrated microcontroller. The inertial measurement unit is available for a multitude of automotive applications as well as for future advanced driver assistance systems functions and automated driving.
# 49
# STATIC:For added comfort and greater efficiency, this speed information is shared with other systems in the car. The predictive adaptive cruise control (pACC) and the predictive efficiency assistant (PEA) use these current data from the cloud for an anticipatory driving style. In the future, these systems will observe these temporary speed limits even before they enter the camera’s field of view.
# CONT:Yet despite all this progress in automation, drivers remain in control. Just as today they can already decide whether they would like to have an assistance system in their vehicle, they can also decide while driving whether they want to use an assistance system that has been installed, such as adaptive cruise control.
# 50
# STATIC:The adaptive cruise assist, which customers know from many of the full-size models, assists with longitudinal and lateral guidance. It maintains the speed and distance to the vehicle in front and assists with lane guidance by means of gentle interventions in the electromechanical steering. This increases the level of ride comfort during long journeys in particular.
# CONT:Customers can pay more for adaptive cruise control, blind-spot information and cross-traffic alert.
# 51
# STATIC:An important system in the assist package “Tour” is the adaptive cruise control including stop & go function – it maintains the distance from the car in front and regulates the vehicle’s speed in line with speed limits as well as for intersections, traffic circles and curves. At speeds of up to 65 km/h
# CONT:An important system in the assist package “Tour” is the adaptive cruise control including stop & go function – it maintains the distance from the car in front and regulates the vehicle’s speed in line with speed limits as well as for intersections, traffic circles and curves. At speeds of up to 65 km/h
# 52
# STATIC:The adaptive cruise assist takes over steering, accelerating, and decelerating for the driver in many situations. The improved restarting comfort is a new feature: Even after a longer standstill, the adaptive cruise assist gets the car start rolling again if the car in front starts moving. A capacitive steering wheel will follow later. It takes only a slight touch for the car to detect that the driver is taking responsibility for steering and automatic lateral guidance can remain active.
# CONT:With up to 39 driver assistance systems the new A6 sets new standards in the premium class. It is thus the ideal choice for high-mileage drivers, fleet customers and commuters. The driver assistance systems with refined control mechanisms enhance convenience and additional support for drivers’ tasks. This includes the adaptive cruise assist, which besides adaptive cruise control and the predictive efficiency assist also comprises the bottleneck assist and thus assist the driver with maneuvering the vehicle longitudinally in roadworks. Also included are the traffic jam assist and the Audi active lane assist, which helps keep the vehicle in lane with gentle steering intervention. Emergency assist enhances safety by bringing the vehicle to a stop in an emergency and making an emergency call. These and other functions are brought together in the “Tour” assist package. The various driver assistance systems are bundled in the three packages “Park,” “City” and “Tour.” The “City” assist package includes features such as the new crossing assist.
# 53
# STATIC:Audi drive select is a standard feature in the RS 5 Cabriolet. The driver can use this function to vary the characteristics of the steering system, seven-speed S tronic, throttle valves and exhaust system sound flaps to one of the modes comfort, auto or dynamic; if an MMI navigation system is installed, the ‘individual’ mode is also offered. The sport differential, adaptive cruise control and dynamic steering – whose gear ratio can be varied by nearly 100 percent as a function of vehicle speed – can also be incorporated into the system.
# CONT:Even more safety is assured by the interaction between the Connected Horizon and driver assistance systems that automatically react to the dangers identified by the system. To name one example, the adaptive cruise control (ACC) can use the latest information from the Connected Horizon to automatically slow down ahead of the tail end of a traffic jam, or alternatively adapt speed autonomously to upcoming bends or speed limits in force along the route. Predictive control of the vehicle’s headlights is another example made possible by the Connected Horizon.
# 54
# STATIC:When the optional adaptive cruise assist including the radar cruise control is active, the PEA assists the driver not only with decelerating but also with fuel-efficient acceleration. If it is switched off, the driver receives prompts that indicate when it would be sensible to take their foot off the right-hand pedal. The driver feels an impulse in the active accelerator pedal and sees information displayed in the Audi virtual cockpit (standard) and on the head-up display (optional). Detailed symbols, e.g. for intersections, town signs and vehicles driving in front, explain the reason for the reduction in speed.
# CONT:Efficiency assist helps the driver to drive preemptively and save fuel. The system works closely together with adaptive cruise control (ACC) or adaptive cruise assist (ACA). It accesses predictive route data from navigation and Car-to-X information. In order to detect traffic signs and other vehicles, the efficiency assist uses the front camera as well as data from the front and rear-facing radar sensors.
# 55
# STATIC:Both models come with numerous assist systems. The standard efficiency assist supports an economical driving style by means of predictive information and, if requested, automatic recuperation. In conjunction with the optional adaptive cruise assist, the system detects the traffic environment and the course of the road by means of sensor and navigation data as well as Car-to-X information. In this way, it can decelerate and accelerate the car predictively. The central driver assistance controller uses the data provided by the sensors to continuously compute a model of the vehicle environment and makes it available to all assist systems.
# CONT:Since the introduction of the ABS brake system in the year 1978, a steady stream of new driver assistance systems that increasingly automate road traffic has been developed. Systems such as lane departure warning, cruise control and adaptive cruise control (ACC) or the electronic stability programme (ESP) relieve the driver’s workload and make road traffic safer and more comfortable. Ever more driving tasks can gradually be taken over by automated systems. Driver assistance systems have been helping to lower the number of road traffic accidents for years. However, they cannot yet avoid them completely. In order to ensure fast help in the event of an accident, the electronic emergency call system “eCall” has been developed and will be mandatory in all new cars as of 2018. It registers accidents and automatically sends out an emergency call.
# 56
# STATIC:The suspension with damper control is connected both to Audi drive select and to the electronic dynamic handling system. In addition to the adaptive dampers, it also controls the brake interventions of the wheel-selective torque control, where it works closely together with the ESC stabilization control. The system aims to harmonize the real behavior of the car with a digital target model so that the transverse dynamics and driving safety are always at the optimum level.
# CONT:The new 10.25-inch integrated connectivity cluster implements the first fully integrated split screen for motorcycles for more comfort and safety. The full-color TFT display combines relevant information and allows a rider-friendly use before, during and after the ride. From the speed to the control of advanced rider assistance systems (ARAS) such as the Adaptive Cruise Control (ACC), the rider has everything at a glance. The cluster is also able to make additional functions of the motorcycle visible and easy to control for the rider.
# 57
# STATIC:Even more safety is assured by the interaction between the Connected Horizon and driver assistance systems that automatically react to the dangers identified by the system. To name one example, the adaptive cruise control (ACC) can use the latest information from the Connected Horizon to automatically slow down ahead of the tail end of a traffic jam, or alternatively adapt speed autonomously to upcoming bends or speed limits in force along the route. Predictive control of the vehicle’s headlights is another example made possible by the Connected Horizon.
# CONT:Both models come with numerous assist systems. The standard efficiency assist supports an economical driving style by means of predictive information and, if requested, automatic recuperation. In conjunction with the optional adaptive cruise assist, the system detects the traffic environment and the course of the road by means of sensor and navigation data as well as Car-to-X information. In this way, it can decelerate and accelerate the car predictively. The central driver assistance controller uses the data provided by the sensors to continuously compute a model of the vehicle environment and makes it available to all assist systems.
# 58
# STATIC:Whether cornering behavior, transverse dynamics or ride comfort – the advantages of the highly networked control system can be felt everywhere. In addition, the driver can himself adjust the settings with the
# CONT:The Lane Keeping Assist system proactively supports the driver by keeping the vehicle in the center of the lane within a full speed range. The system aims to increase comfort by supporting the driver with his lateral control task. It requires the driver to keep his hands on the steering wheel. The LKA system can be coupled with adaptive cruise control (ACC) to support both longitudinal and lateral control at the same time. The system can be easily overruled by the driver at any time.
# 59
# STATIC:Those wishing to drive particularly efficiently can supplement the ACA with predictive control and the efficiency assist. This enables an anticipatory driving style. To detect the traffic situation and the course of the route, the ACA analyzes camera images – including images of traffic signs – plus the navigation data. If the adaptive cruise assist is deactivated, the
# CONT:with the S line sport package or the adaptive damper control system
# 60
# STATIC:, lane departure warning, cruise control and speed limiter are standard equipment. Additional systems are available individually, while others are bundled into the City and Tour assist packages.
# CONT:The A4 models are available with a host of driver assistance systems. The optional systems are bundled into the “Tour,” “City” and “Park” packages. An important system in the “Tour” package is the adaptive cruise control including stop & go function for automatic distance control. In conjunction with the predictive
# 61
# STATIC:The Lane Keeping Assist system proactively supports the driver by keeping the vehicle in the center of the lane within a full speed range. The system aims to increase comfort by supporting the driver with his lateral control task. It requires the driver to keep his hands on the steering wheel. The LKA system can be coupled with adaptive cruise control (ACC) to support both longitudinal and lateral control at the same time. The system can be easily overruled by the driver at any time.
# CONT:With our third generation radar sensor a predictive Emergency Brake Assist system can be triggered. It responds by activating an automatic braking system as soon as the driver’s own vehicle comes within a dangerous distance to a preceding vehicle and the driver does not respond appropriately. As a result, it can considerably reduce stopping distance. These kinds of safety functions are already integrated into modern Adaptive Cruise Control (ACC) systems today. The Emergency Brake Assist system fulfills the new EU safety regulations for driver assistance systems in commercial vehicles.
# 62
# STATIC:models, when cruising up to a red traffic light, will make increased used of braking energy in order to charge their batteries. Coupled with predictive adaptive cruise control (pACC), the cars could even brake automatically at red lights.
# CONT:The “Drive” package comprises multiple elements: the navigation package, the Audi virtual cockpit, the emergency assist, traffic sign recognition via camera, cruise control, and the adaptive cruise assist which is based upon it. In many situations, it can assist the driver with accelerating, decelerating, and steering within the lane.
# 63
# ...
# 81
# STATIC:The optional efficiency assist can also contribute to an economical driving style. The system instructs the driver when to release the accelerator, before entering a curve or behind a slow vehicle, for example. If desired, the system automatically regulates acceleration and deceleration. It utilizes predictive route data from the navigation system and information from Audi connect. The on-board sensors supply the system with findings on traffic signs and other vehicles.
# CONT:of the predecessor model and extends it with multiple systems, such as the predictive efficiency assist with camera-based traffic sign recognition and navigation data-based cruise control. A lane tracking function for narrow stretches and in traffic jams is also included. For greater efficiency, the powertrain management of the standard mild hybrid system is integrated into the
# 82
# STATIC:More than 30 driver assist systems are available for the RS 5 models**. The parking system plus, cruise control, traffic sign recognition, and Audi side assist are available as standard. The optional systems have been bundled into the “Drive” and “Park” packages. The “drive” assist package already includes adaptive cruise control with “stop and go” and Audi pre sense rear, including pre sense basic. The lane keeping assist and lane change warning are part of the optional package.
# CONT:Besides the Audi AI systems, the new A7 Sportback features a total of 39 driver assistance systems to make things easier for the driver. They are split up into three packages: the Audi AI parking package (gradual introduction beginning 2018), the City assist package with the new crossing assist, and the Tour assist package. The latter includes such things as the efficiency assistant, which facilitates a driving style conducive to reducing consumption, and the adaptive driving assistant (ADA), which supplements the adaptive cruise control (ACC) with helpful steering interventions to maintain the lane. All driver assistance systems feature improved control mechanisms.
# 83
# STATIC:On many transmissions, a gear change is made by means of a hydraulic controller activated by a transmission control unit. Intelligent control software adjusts the switching behavior of the automatic transmission to the actual driving situation. By controlling the electrohydraulic or electromechanic transmission actuators, the transmission control unit makes comfortable and dynamic driving performance possible. It also performs a diagnosis of the automatic transmission and its components.
# CONT:The optional efficiency assist can also contribute to an economical driving style. The system instructs the driver when to release the accelerator, before entering a curve or behind a slow vehicle, for example. If desired, the system automatically regulates acceleration and deceleration. It utilizes predictive route data from the navigation system and information from Audi connect. The on-board sensors supply the system with findings on traffic signs and other vehicles.
# 84
# STATIC:The technology in driver assistance systems potentially offers additional significant reductions in the number of accidents and traffic jams. Adaptive cruise control systems, for example, improve the traffic flow and make a major contribution to avoiding accidents.
# CONT:The basic variant of the headlamp control can automatically activate or deactivate the vehicle’s low beam lights in accordance with the current lighting conditions. The function improves driver visibility at night by automatically controlling the on/off function of the vehicle high beams through traffic detection.
# 85
# STATIC:XTRONIC CVT is also characterized by its adaptive shift control, which interprets the driver intentions from the acceleration and steering to provide optimum shift control. Coordinated control between engine and transmission delivers optimal fuel consumption performance and driving performance.
# CONT:The path to automated driving will appear familiar to many: today a customer can configure their desired car such that on the one hand it has today’s driver assistance features (e.g. lane keeping assistant, adaptive cruise control with emergency braking, and highway driving assistant) for driving on the highway. On the other hand, they can decide to go without all the parking assistance systems that support the driver during maneuvering. In the future customers will still have this freedom of choice.
# 86
# STATIC:Yet despite all this progress in automation, drivers remain in control. Just as today they can already decide whether they would like to have an assistance system in their vehicle, they can also decide while driving whether they want to use an assistance system that has been installed, such as adaptive cruise control.
# CONT:Safety equipment includes forward-collision warning, lane-departure warning, blind-sport warning and, for the first time in an Aston Martin, adaptive cruise control and lane keep assist.
# 87
# STATIC:, the electronic stabilization control automatically switches to stability, traction and braking control modes that are optimized for off-road driving. The standard hill descent control system is also activated. It provides support by means of automatic brake interventions when driving down a steep gradient that exceeds six percent. The electronic chassis platform captures the tilt angle of the car and displays this information for the driver on the MMI. At off-road level, the angles of approach/departure of the new RS Q8** are 21.6 degrees at the front and 26.2 degrees at the rear.
# CONT:accelerator-pedal position and any system requirements that can influence the engine torque, such as cruise control, or active safety systems such as the electronic stability program ESP®.
# 88
# STATIC:the performance of traffic sign information can be further optimized. With this, the system supports the future legal requirements of the General Safety Regulation (GSR) for the Intelligent Speed ​​Limit Assist with regards to the detection of speed limits and warning when speeding.
# CONT:mode can be used. In this mode, the electronic stabilization control switches the traction control system over to off-road mode. As an option, the hill descent control can provide support here. It constantly maintains the speed specified by the driver (up to 30 km/h
# 89
# STATIC:In conjunction with driver assistance systems, the Connected Horizon makes smart, partially automated vehicle control possible. Among other things, this opens up the possibility of automatic speed regulation on highways or autonomous vehicle deceleration ahead of the tail ends of traffic jams. Furthermore, fuel consumption and the associated operating costs of the vehicle can be reduced through predictive speed selection and coasting strategies.
# CONT:. The ESC switches to a stability, traction, and brake regulation that is tailored to use on dirt roads. The standard hill descent control is also activated. It assists the driver by means of automatic brake interventions when driving down a steep gradient that exceeds six percent.
# 90
# STATIC:In order to maintain lateral guidance, the driver need only gently touch the capacitive steering wheel, which is part of the system, to prove that they are paying attention. The adaptive cruise assist operates up to a speed of 210 km/h
# CONT:Detection of implicit and explicit speed limitation signs to inform the driver about the maximum allowed velocity. It includes detection of conditional speed limits by Supplementary Sign Optical Character Reading. Optionally, SLA can be extended to an Intelligent Speed Assist (ISA) by adapting the cruise control with speed limit information from traffic sign recognition.
# 91
# STATIC:The new 10.25-inch integrated connectivity cluster implements the first fully integrated split screen for motorcycles for more comfort and safety. The full-color TFT display combines relevant information and allows a rider-friendly use before, during and after the ride. From the speed to the control of advanced rider assistance systems (ARAS) such as the Adaptive Cruise Control (ACC), the rider has everything at a glance. The cluster is also able to make additional functions of the motorcycle visible and easy to control for the rider.
# CONT:In May, ZF and Intel's Mobileye unit said they will jointly develop advanced safety systems -- including automatic emergency braking, adaptive cruise control and lane keeping systems -- for Toyota.
# 92
# STATIC:Besides the Audi AI systems, the new A7 Sportback features a total of 39 driver assistance systems to make things easier for the driver. They are split up into three packages: the Audi AI parking package (gradual introduction beginning 2018), the City assist package with the new crossing assist, and the Tour assist package. The latter includes such things as the efficiency assistant, which facilitates a driving style conducive to reducing consumption, and the adaptive driving assistant (ADA), which supplements the adaptive cruise control (ACC) with helpful steering interventions to maintain the lane. All driver assistance systems feature improved control mechanisms.
# CONT:The camera’s design fully satisfies the requirements of driver assistance systems to enhance safety, comfort, convenience, and efficiency. Its detection characteristics make it suitable for a wide range of partially automated functions, such as lane departure warning assistants. The camera satisfies numerous legal requirements, such as UN regulation UN-ECE R130 concerning the lane departure warning system (LDWS) in Europe, in addition to the many functions mandated by regional laws. In addition, the camera supports object-based functions for automatic emergency braking or adaptive cruise control (ACC) by supplying a control unit with relevant information via the integrated system interface.
# 93
# STATIC:with the standard suspension. In the offroad mode of Audi drive select, the Electronic Stabilization Control adapts its regulatory activities to the conditions that exist off the beaten track. On loose surfaces, it ensures increased traction and optimized brake interventions. The standard hill descent control is also active in offroad mode. In all other drive select modes, it can be activated separately. It constantly maintains the speed specified by the driver up to 30 km/h
# CONT:The new Audi RS Q8** supports the driver in many situations. The comprehensive range of over 30 assist systems includes such things as the adaptive cruise assist, efficiency assist, intersection assist, lane change warning and 360 degree cameras.
# 94
# STATIC:The updated Q5 also comes with a comprehensive set of assistance systems. The Audi pre sense city system comes as standard, and helps avoid collisions with road users in front of the vehicle or mitigate their consequences. The optional turn assist, collision avoidance assist and exit warning systems also contribute to overall safety. Adaptive cruise assist can largely relieve the driver of accelerating, braking and lane-keeping maneuvers for long periods, while predictive efficiency assist supports an anticipatory driving style and lowers fuel consumption.
# CONT:safety systems as well as the lane departure warning system and cruise control system are standard features. The optional systems are subdivided into the “Tour,” “City,” and “Park” packages, which are combined in the assist system plus. The
# 95
# STATIC:. The ESC switches to a stability, traction, and brake regulation that is tailored to use on dirt roads. The standard hill descent control is also activated. It assists the driver by means of automatic brake interventions when driving down a steep gradient that exceeds six percent.
# CONT:On many transmissions, a gear change is made by means of a hydraulic controller activated by a transmission control unit. Intelligent control software adjusts the switching behavior of the automatic transmission to the actual driving situation. By controlling the electrohydraulic or electromechanic transmission actuators, the transmission control unit makes comfortable and dynamic driving performance possible. It also performs a diagnosis of the automatic transmission and its components.
# 96
# STATIC:The new Audi RS Q8** supports the driver in many situations. The comprehensive range of over 30 assist systems includes such things as the adaptive cruise assist, efficiency assist, intersection assist, lane change warning and 360 degree cameras.
# CONT:system influences the engine and transmission management, the power steering, the suspension, the dynamic all-wheel steering, the quattro sport differential, the engine sound and the way in which the automatic air conditioning works. In “RS2” mode, customers can also switch the Electronic Stabilization Control (ESC) to sport mode at the touch of a button and save this setting permanently. If the driver presses the ESP button for more than three seconds, the Electronic Stabilization Control is deactivated completely.
# 97
# STATIC:The basic variant of the headlamp control can automatically activate or deactivate the vehicle’s low beam lights in accordance with the current lighting conditions. The function improves driver visibility at night by automatically controlling the on/off function of the vehicle high beams through traffic detection.
# CONT:Whether cornering behavior, transverse dynamics or ride comfort – the advantages of the highly networked control system can be felt everywhere. In addition, the driver can himself adjust the settings with the
# 98
# STATIC:With up to 39 driver assistance systems the new A6 sets new standards in the premium class. It is thus the ideal choice for high-mileage drivers, fleet customers and commuters. The driver assistance systems with refined control mechanisms enhance convenience and additional support for drivers’ tasks. This includes the adaptive cruise assist, which besides adaptive cruise control and the predictive efficiency assist also comprises the bottleneck assist and thus assist the driver with maneuvering the vehicle longitudinally in roadworks. Also included are the traffic jam assist and the Audi active lane assist, which helps keep the vehicle in lane with gentle steering intervention. Emergency assist enhances safety by bringing the vehicle to a stop in an emergency and making an emergency call. These and other functions are brought together in the “Tour” assist package. The various driver assistance systems are bundled in the three packages “Park,” “City” and “Tour.” The “City” assist package includes features such as the new crossing assist.
# CONT:A range of driver assist technology will be available, including standard emergency braking, driver alert, adjustable speed limiting, cruise control and lane-keeping.
# 99
# STATIC:prototype will decelerate using the electric motor, the wheel brake, or a combination of the two. The brake pedal is decoupled from the hydraulic system. The transition from the engine brake to the pure friction brake is smooth, and the driver does not notice it. This system allows the electric SUV to exploit its maximum recuperation potential in a targeted manner with support from the standard efficiency assist. The system uses radar sensors, camera images, navigation data and Car-to-X information to detect the traffic environment and the route. The driver is shown corresponding information in the Audi virtual cockpit as soon as it would be sensible to take the foot off the accelerator pedal. By interacting with the optional adaptive cruise assist, the efficiency assist can also decelerate and accelerate the electric SUV predictively.
# CONT:the performance of traffic sign information can be further optimized. With this, the system supports the future legal requirements of the General Safety Regulation (GSR) for the Intelligent Speed ​​Limit Assist with regards to the detection of speed limits and warning when speeding.

# %%
l_count = []
for doc in en_ret_docs[:10]:
    l_count.append(len(doc.split(" ")))
    
print(f"{np.mean(np.asarray(l_count))}")


l_count = []
for doc in retrieved['en_docs'][:10]:
    l_count.append(len(doc.split(" ")))
    
print(f"{np.mean(np.asarray(l_count))}")
# Out:
# 43.7
# 24.6

# %%
def get_sent_vector_contextual(sent):
    with torch.no_grad():
        inputs = tokenizer(sent, return_tensors='pt',
                      max_length=512, padding=True, truncation=True).to('cuda')
        output = cont_model(**inputs, output_hidden_states=True, output_attentions=True)
    
    # last layer gives the best embeddings
    token_embeddings = output['hidden_states'][-1] 
    # Mean Pooling - Take attention mask into account for correct averaging
    input_mask_expanded = inputs['attention_mask'].unsqueeze(-1).expand(token_embeddings.size()).float()
    sent_embedding = torch.sum(token_embeddings * input_mask_expanded, 1) / torch.clamp(input_mask_expanded.sum(1), min=1e-9)
    return np.asarray(sent_embedding.cpu())

# %%
def sort_dict(dict_to_sort):
    return dict(sorted(dict_to_sort.items(), key=lambda item: item[1]))

# %%
def get_imp_word(query):
    query_vec = encoding.encode(sent=[query])
    word_import = {}
    for word in query.split(" "):
        word_vec = encoding.encode(sent=[word])
        word_import[word] = cosine_similarity(word_vec, query_vec)[0]
    word_import = sort_dict(word_import)
    imp_word = list(word_import.keys())[-1]
    return imp_word

# %%
imp_word = get_imp_word(query)
imp_word

# %%
word_vec = get_sent_vector_contextual(sent=[imp_word])
# word_vec = cont_encoding.encode(sent=[imp_word])
word_vec.shape

# %%
docs_with_word_idx = [idx for idx, doc in enumerate(scraped_en_docs) if imp_word in doc][:100]
docs_with_word = [scraped_en_docs[idx] for idx in docs_with_word_idx]

# %%
docs_with_word_vec = get_sent_vector_contextual(docs_with_word)
# docs_with_word_vec = cont_encoding.encode(docs_with_word)
total_len = len(docs_with_word_vec)
docs_with_word_vec.shape

# %%
sim = cosine_similarity(word_vec, Y=docs_with_word_vec, 
                           dense_output=True)[0]

# %%
np.argsort(sim), sim[np.argsort(sim)[0]], sim[np.argsort(sim)[-1]]

# %%
ind = np.argsort(sim)[:10]
idxs = [docs_with_word_idx[idx] for idx in ind]
other_docs = [scraped_en_docs[idx] for idx in idxs]
other_docs

# %%
en_ret_docs_vecs = get_sent_vector_contextual(en_ret_docs)
other_docs_vecs = get_sent_vector_contextual(other_docs)
query_vec = get_sent_vector_contextual(query)

# %%
en_ret_docs_vecs.shape, other_docs_vecs.shape, query_vec.shape

# %%
vectors = []
vectors.extend(query_vec)
vectors.extend(en_ret_docs_vecs)
vectors.extend(other_docs_vecs)
vectors = np.asarray(vectors)
vectors.shape

# %%
proj_2d = projection.get_projection_2d(vectors)

# %%
query_proj = proj_2d[:1]
ret_docs_proj = proj_2d[1:len(en_ret_docs)+1]
other_docs_proj = proj_2d[len(en_ret_docs)+1:]

# %%
query_proj.shape, ret_docs_proj.shape, other_docs_proj.shape

# %%
def plot_umap_intra_sim(query, en_ret_docs, other_docs, imp_word, proj_2d):
    def strip_text(doc, word):
        sp = doc.split(" ")
        index = [idx for idx, s in enumerate(sp) if word in s][0]
        return " ".join(doc.split(" ")[index-20:index+20])
            
    ret_colors = []
    ret_docs = []
    ret_projs = []
    
    query_proj = proj_2d[:1]
    ret_docs_proj = proj_2d[1:len(en_ret_docs)+1]
    other_docs_proj = proj_2d[len(en_ret_docs)+1:]
            
    for doc, proj in zip(en_ret_docs, ret_docs_proj):
        ret_colors.append('red')
        ret_docs.append(doc)
        ret_projs.append(proj)
        
    for doc, proj in zip(other_docs, other_docs_proj):
        ret_colors.append('blue')
        stripped_doc = strip_text(doc, imp_word)
        ret_docs.append(stripped_doc)
        ret_projs.append(proj)
            
    ret_docs.append(query)
    ret_colors.append('green')
    ret_projs.extend(query_proj)
    
    projection.plot_umap_2d(ret_docs, ret_projs, ret_colors)

# %%
plot_umap_intra_sim(query, en_ret_docs, other_docs, imp_word, proj_2d)

# %% [markdown]
# ## Try to explain with attentions

# %%
pd.set_option('display.max_rows', 500)

# %%
def get_output(sent_1, sent_2=None):
    with torch.no_grad():
        if sent_2:
            inputs = tokenizer(sent_1, sent_2, return_tensors='pt',
                          max_length=512, padding=True, truncation=True).to('cuda')
        else:
            inputs = tokenizer(sent_1, return_tensors='pt',
                          max_length=512, padding=True, truncation=True).to('cuda')            
        output = cont_model(**inputs, output_hidden_states=True, output_attentions=True)
    return inputs, output

# %%
# output['attentions'] --> tuple of length 12 --> 12 layers
# each layer has torch.Size([1, 12, 6, 6])
# 12 heads, num of tokens, num of tokens

# %%
def get_tokens(inputs):
    input_id_list = inputs['input_ids'][0].tolist() # Batch index 0
    tokens = tokenizer.convert_ids_to_tokens(input_id_list)  
    query_tokens = tokens[tokens.index('[CLS]')+1: tokens.index('[SEP]')]
    doc_tokens = tokens[tokens.index('[SEP]')+1:]
    # print(f"There are {len(tokens)} tokens: {tokens}")
    return tokens, query_tokens, doc_tokens

# %%
{f"head_{head}": "" for head in range(6)}
# Out:
# {'head_0': '',
#  'head_1': '',
#  'head_2': '',
#  'head_3': '',
#  'head_4': '',
#  'head_5': ''}

# %%
import numpy as np
def show_attention(output, tokens, layer=11, only_query_tokens=False, query_tokens=None):
    num_heads = 12
    print(f"Attention of Layer: {layer}")
    df = []
    for ind, token in enumerate(tokens):
        df_token = {f"head_{head}": "" for head in range(6)}
        df_token["token"] = token
        for head in range(num_heads):
            attention = output.attentions[layer][0][head][ind]
            # indices = np.argsort(attention.cpu().numpy())[::-1][-1:]
            indices = np.argsort(attention.cpu().numpy())[::-1][-5:]
            if only_query_tokens:
                df_token[f"head_{head}"] = ' '.join([tokens[idx] for idx in indices if tokens[idx] in query_tokens])
            else:
                df_token[f"head_{head}"] = ' '.join([tokens[idx] for idx in indices])
        df.append(df_token)
    
    df = pd.DataFrame(df)
    tokens_col = df.pop("token")
    df.insert(0, "token", tokens_col)
    
    return df

# %%
sent = 'automatic emergency braking'
inputs, output = get_output(sent_1=sent)
tokens, query_tokens, doc_tokens = get_tokens(inputs)
df = show_attention(output=output, tokens=tokens, layer=11)
df
# Out:
# Attention of Layer: 11
#        token                                head_0  \
# 0      [CLS]  brak ##ing automatic emergency [CLS]
# 1  automatic  automatic [CLS] emergency brak ##ing
# 2  emergency  emergency brak automatic [CLS] ##ing
# 3       brak  [CLS] brak ##ing automatic emergency
# 4      ##ing  brak [CLS] ##ing automatic emergency
# 5      [SEP]      [CLS] ##ing brak [SEP] emergency
#
#                                   head_1  \
# 0   ##ing automatic brak emergency [CLS]
# 1       emergency [SEP] ##ing brak [CLS]
# 2       automatic [SEP] brak ##ing [CLS]
# 3  emergency [SEP] automatic ##ing [CLS]
# 4   [SEP] automatic brak emergency [CLS]
# 5   automatic brak emergency ##ing [CLS]
#
#                                   head_2  \
# 0   automatic [SEP] brak emergency [CLS]
# 1       emergency [SEP] ##ing brak [CLS]
# 2       automatic [SEP] brak ##ing [CLS]
# 3  [SEP] emergency ##ing automatic [CLS]
# 4   [SEP] brak automatic emergency [CLS]
# 5   brak automatic emergency ##ing [CLS]
#
#                                   head_3  \
# 0       ##ing brak [SEP] emergency [CLS]
# 1       [SEP] emergency brak ##ing [CLS]
# 2   emergency automatic brak ##ing [CLS]
# 3  [SEP] ##ing emergency automatic [CLS]
# 4   [SEP] brak automatic [CLS] emergency
# 5   brak ##ing automatic emergency [CLS]
#
#                                   head_4  \
# 0       emergency ##ing [SEP] brak [CLS]
# 1       emergency [SEP] ##ing brak [CLS]
# 2       automatic [SEP] brak ##ing [CLS]
# 3  [SEP] emergency automatic ##ing [CLS]
# 4   [SEP] automatic emergency brak [CLS]
# 5   brak emergency automatic ##ing [CLS]
#
#                                   head_5  \
# 0   brak ##ing [CLS] automatic emergency
# 1       emergency [SEP] ##ing [CLS] brak
# 2       automatic [SEP] ##ing brak [CLS]
# 3  [SEP] ##ing automatic emergency [CLS]
# 4   [SEP] automatic brak [CLS] emergency
# 5   brak automatic emergency ##ing [CLS]
#
#                                  head_6  \
# 0  automatic brak emergency [CLS] [SEP]
# 1  automatic emergency ##ing brak [CLS]
# 2  emergency brak automatic ##ing [CLS]
# 3  [SEP] brak emergency automatic [CLS]
# 4  automatic ##ing brak [CLS] emergency
# 5  brak emergency automatic ##ing [CLS]
#
#                                   head_7  \
# 0  automatic ##ing [SEP] emergency [CLS]
# 1   ##ing automatic brak [CLS] emergency
# 2   brak emergency ##ing automatic [CLS]
# 3   automatic brak ##ing emergency [CLS]
# 4   ##ing brak automatic emergency [CLS]
# 5   [CLS] brak ##ing automatic emergency
#
#                                  head_8                                head_9  \
# 0      emergency ##ing brak [SEP] [CLS]  [CLS] ##ing brak automatic emergency
# 1  ##ing automatic emergency brak [CLS]  automatic ##ing emergency brak [CLS]
# 2  ##ing automatic emergency brak [CLS]  emergency automatic brak ##ing [CLS]
# 3  ##ing [CLS] automatic brak emergency  brak ##ing emergency automatic [CLS]
# 4  ##ing emergency automatic [CLS] brak  ##ing brak [CLS] automatic emergency
# 5  brak emergency [CLS] automatic ##ing  automatic brak ##ing emergency [CLS]
#
#                                 head_10                               head_11
# 0  automatic ##ing brak [CLS] emergency  automatic ##ing brak emergency [CLS]
# 1  automatic [CLS] brak ##ing emergency  automatic emergency [CLS] ##ing brak
# 2  brak automatic emergency [CLS] ##ing  emergency brak automatic ##ing [CLS]
# 3  brak automatic ##ing emergency [CLS]  brak ##ing emergency [CLS] automatic
# 4  ##ing brak automatic [CLS] emergency  ##ing [CLS] brak automatic emergency
# 5  brak emergency automatic ##ing [CLS]  automatic brak emergency ##ing [CLS]

# %%
head_view(attention=output.attentions,
            tokens=tokens,
            sentence_b_start=6,
            prettify_tokens=False,
            layer=11,
            heads=None
         )

# %%
query, doc = 'adaptive cruise control', en_ret_docs[0]
inputs, output = get_output(sent_1=query, sent_2=doc)
tokens, query_tokens, doc_tokens = get_tokens(inputs)
df = show_attention(output=output, tokens=tokens, layer=11, only_query_tokens=False, query_tokens=query_tokens)
df
# Out:
# Attention of Layer: 11
#          token                                head_0  \
# 0        [CLS]  ada control ##ptive especially dense
# 1          ada        dense more end especially rear
# 2      ##ptive     dense prevent end especially rear
# 3       cruise     prevent dense end rear especially
# 4      control           - especially dense rear end
# 5        [SEP]               help prevent rear . ##s
# 6          ada          help dense prevent more rear
# 7      ##ptive          in dense especially end rear
# 8       cruise     prevent end especially dense rear
# 9      control          especially in end dense rear
# 10       makes                   in - dense end rear
# 11      riding            dense ##ptive rear ada end
# 12        more            ada cruise cruise rear end
# 13         con            ada cruise cruise rear end
# 14      ##veni      dense cruise especially end rear
# 15       ##ent                 ada - cruise rear end
# 16         for               ada ada cruise rear end
# 17         the           ##ptive ada cruise rear end
# 18       rider                rear dense ada ada end
# 19           ,              ada rear ##ptive ada end
# 20  especially               cruise ada ada end rear
# 21          in              ##ptive more end ada ada
# 22       dense            help control ada ada makes
# 23     traffic         makes control ##ptive ada ada
# 24           ,           ##ptive end ##ptive ada ada
# 25         and            cruise ada cruise rear end
# 26       could          cruise cruise dense rear end
# 27        help             cruise ada rear end dense
# 28          to               cruise end in ada dense
# 29     prevent     ##ptive more ada dense especially
# 30        rear     ada especially control more makes
# 31           -     more control ada especially makes
# 32         end         con ada more especially makes
# 33   collision         ada more makes especially ada
# 34         ##s       for ##ptive more ada especially
# 35           .               for ada con ##ptive ada
# 36       [SEP]               help prevent rear . ##s
#
#                                     head_1  \
# 0              ##ptive ##s collision - end
# 1                           to the , - ##s
# 2                          and ##s the , ,
# 3                           to , and - ##s
# 4                          ##s , to rear -
# 5                              . , ##s , -
# 6                            - , the , ##s
# 7                          the for , , ##s
# 8                           - , to and ##s
# 9                          , rear ##s to -
# 10                collision rear ##s end -
# 11                         , ada and ##s -
# 12                         the , ada ##s -
# 13                         , the and ##s -
# 14                           ##s , in to -
# 15                   the cruise rear ada -
# 16               ##ptive ##s ada ##ptive -
# 17               ##s ##ptive ##ptive ada -
# 18                        ada to and ##s -
# 19            cruise ada ##ptive ##ptive -
# 20                      rear the ##s end -
# 21                ##veni ##ptive ada ##s -
# 22                          to , - ##s and
# 23                     ##veni and ada - to
# 24       cruise cruise ##ptive ada ##ptive
# 25                collision rear end ada -
# 26                 collision ##s ada end -
# 27                         , ##s end ada -
# 28                cruise control - ada ada
# 29                     , ##ptive ##s the -
# 30           control makes control and ##s
# 31  ##ent especially control control makes
# 32            control control and to makes
# 33                    ##ptive , the to and
# 34             makes cruise ada cruise ada
# 35                ##s ##ptive ada ##veni -
# 36                             . , ##s , -
#
#                                   head_2                              head_3  \
# 0                 ##veni for end ##ent -          ##ent ada ada ##veni [CLS]
# 1                        end , for - ##s                   - ##ent , ##s end
# 2                         to ##s for , ,                  traffic to con , ,
# 3                          and ##s , - ,                      ##s , and to ,
# 4                         end , , rear -                     , to end rear -
# 5                        , ##ent ##s , -               ##ptive ada - ada con
# 6                        - for end , ##s                 control , - ##s end
# 7                        and ##s for , ,                      end to ##s , ,
# 8                          - and , ##s ,                      . ##s to and ,
# 9                          in , rear , -                     rear and , to -
# 10                      , rear ##s end -              ##ptive rear ##s end -
# 11                  ##ptive rear , ada -           ##ptive ada - ##ptive ada
# 12                   end , ##ptive ##s -               end ada ##ptive ada -
# 13                     and . , ##ptive -           ##ptive end - ##ptive ada
# 14                       , rear ##s to -                     in rear , end .
# 15                ##ptive ada rear ada -               end cruise rear - ada
# 16               ##ptive , ada ##ptive -           end ##ptive - ada ##ptive
# 17                   ada end ##ent ##s -        cruise ##ptive - ada ##ptive
# 18                         and , , ##s -                    to end ##s - ada
# 19          cruise end - ##ptive ##ptive        - cruise ##ptive ada ##ptive
# 20                 the end ##s ##ptive -         cruise ##ptive ada cruise -
# 21            ##veni ##ent ada ##ptive -        ##veni control ##ptive ada -
# 22                         . , and ##s -                   and ada , ada ##s
# 23                  ada ##ptive to ada -          to ##ptive ##ptive ada ada
# 24  cruise cruise ##veni ##ptive ##ptive   control cruise cruise ##ptive ada
# 25          end cruise ##ptive ##ptive -            end cruise ##ptive ada -
# 26              collision rear end ##s -              rear ada ##ptive end -
# 27                  rear , ##ptive ada -            cruise ##ptive ada end -
# 28        ##ptive ##veni ##ptive ada ada  control cruise control ada ##ptive
# 29                 ##ptive ##ptive , , -               ##ptive con ada , ada
# 30               , control , control and         ##ent , ada control control
# 31    ada control makes especially ##ent     ada could control makes control
# 32                   makes and , ada ada            control to makes ada ada
# 33                       ada ada , and ,                   and the ada , ada
# 34         cruise ##ptive ##veni ada ada            makes cruise the ada ada
# 35            con ##ent - ##ptive ##veni         cruise - ##veni ##ptive ada
# 36                       , ##ent ##s , -               ##ptive ada - ada con
#
#                             head_4                         head_5  \
# 0                  the , and ada .            con ##veni - to the
# 1               end ##ent , to ##s               for the , to ##s
# 2                for and ##ent , ,                 and to ##s , ,
# 3                 , - ##veni ##s ,                 . ##s and to ,
# 4            end ##veni con rear -                the , rear to -
# 5                 , [CLS] to ##s -                 . and to ##s ,
# 6              traffic , and , ##s               and the to ##s ,
# 7                  ##s and for , ,                 to the and , ,
# 8                    and . , ##s ,               the ##s and to ,
# 9                   , , rear ada -                 and to , the -
# 10        collision rear ##s end -               , ##s rear end -
# 11           , ada ##ptive [CLS] -                 ada , the to -
# 12              ada rear end ##s -                end , ada ##s -
# 13             , and ##ptive - ##s                , and the ada -
# 14                  - ##s . and to                rear the to , -
# 15        collision ada ada rear -              in rear the ada -
# 16           end ada ##ptive ada -            ##s , ##ptive ada -
# 17        ##veni ##ptive ##s ada -             to , ##ptive ada -
# 18              , ##ptive to ##s -               end and to ada -
# 19       ada end ##ptive - ##ptive          rear to - ##ptive ada
# 20        ada to ##ptive ##ptive -           ##ptive end to the -
# 21            ada ada con - ##veni            and to con ##veni -
# 22               [CLS] ##s . , and                 ##s . to , and
# 23         - ##veni to ##ptive ada          the and ##veni to ada
# 24    ada rear ##ptive ada ##ptive         con - rear ##ptive ada
# 25        ##ptive ##veni con - ada         end ##ptive rear ada -
# 26         collision ada end ##s -             rear the end ada -
# 27       ##ptive ##ptive ada ada -           cruise end ada the -
# 28            con ada - ##veni ada      ##ptive ada - ##ptive ada
# 29             ##ptive ada and , -                - , the and ada
# 30           control , and , ##ent  ada control and control makes
# 31  help control makes rider ##ent        makes , ada control and
# 32             makes ada , ada and         could to ada and makes
# 33           the ##ptive ada and ,          ada makes ada and the
# 34          cruise the con ada ada     especially the for ada ada
# 35          cruise to con ##veni -       ##veni con - ##ptive ada
# 36                , [CLS] to ##s -                 . and to ##s ,
#
#                             head_6                          head_7  \
# 0                      . ada , , -       ##ptive con - end prevent
# 1                and help , to for     prevent end ##veni con rear
# 2              ##ent more to , for              , for rear end con
# 3                help and the to ,          prevent con , rear end
# 4                for to rear - end       ##ent ##veni con rear end
# 5                    and , - ##s ,               dense , ##s end -
# 6                and more to for ,          - con prevent end rear
# 7                ##s , more to for        for prevent rear con end
# 8         especially more the , to          , ##s prevent rear end
# 9              more ada - rear end        con ##s prevent rear end
# 10        collision - rear ##s end          ##s prevent - rear end
# 11             the con end ##ent ,    collision , prevent rear end
# 12           collision - end , ##s          - ##s prevent rear end
# 13              ada in rear to end         - help prevent end rear
# 14              end , rear ada ada         help - prevent end rear
# 15               to rear end ##s -  collision ##s prevent rear end
# 16                  , to end ##s -  collision ##s prevent rear end
# 17             cruise to end - ##s       help con rear prevent end
# 18           the end con ##ent for          ##s - prevent rear end
# 19              cruise , end ##s -           - to end prevent rear
# 20      collision end cruise - ##s          ##s - prevent rear end
# 21         ##veni con ##s ##ent to     end ##veni help prevent con
# 22              ada for , makes to     cruise ##ent end ##veni con
# 23           con ##ent ada more to        , prevent ##veni con end
# 24             ##s con ##ent - for    for ##ptive ##veni con ##ent
# 25                 end , for - ##s       ##ent rear end con ##veni
# 26               end rear in - for              ##s con - rear end
# 27         for end cruise cruise -   cruise ada ##ptive ##veni con
# 28         in con for ##ent cruise    ##ptive ##ent for ##veni con
# 29               ##ent ada , , for      for makes ##ent ##veni con
# 30        more control , makes for      makes for ##ent con ##veni
# 31       for control ada ada makes      for makes con ##ent ##veni
# 32          more for ada makes ada      makes for con ##veni ##ent
# 33          ada for makes more ada      makes for ##ent ##veni con
# 34  ##ptive more ##ptive makes ada    control for ##veni ##ent con
# 35                 - con ##s for ,          , for ##ent ##veni con
# 36                   and , - ##s ,               dense , ##s end -
#
#                                    head_8  \
# 0             could help ada ##veni makes
# 1        rear ##veni , especially prevent
# 2            cruise rear ##veni prevent ,
# 3             dense cruise prevent rear ,
# 4           especially , end rear prevent
# 5                  ada con ada end ##veni
# 6       ##veni collision ada help prevent
# 7         , ##veni collision prevent help
# 8       ada cruise collision prevent help
# 9            end , collision prevent help
# 10        rear end prevent collision help
# 11                   , end ada help [CLS]
# 12             ada ada control end cruise
# 13      ##ptive ada help [CLS] especially
# 14            , [CLS] help end especially
# 15        especially ##ptive help ada end
# 16         ada collision help prevent end
# 17         collision ada help end prevent
# 18                 ada end , prevent help
# 19            ada ##veni end rear prevent
# 20  especially collision end help prevent
# 21              rear end ada help prevent
# 22        especially [CLS] , help prevent
# 23               end prevent [CLS] , help
# 24      collision ada rear ##veni prevent
# 25            end rear cruise ada prevent
# 26           rear prevent cruise end help
# 27     especially [CLS] cruise ada cruise
# 28      cruise control ##ptive ada cruise
# 29      help prevent [CLS] ada especially
# 30      ada especially cruise makes [CLS]
# 31   cruise ##veni [CLS] especially makes
# 32         , help cruise makes especially
# 33       especially cruise cruise , [CLS]
# 34     control , cruise cruise especially
# 35                  , con rear ##veni ada
# 36                 ada con ada end ##veni
#
#                                  head_9                       head_10  \
# 0                [CLS] for - end cruise          ada ##s ada rear end
# 1             help ##veni con for ##ent               - , con for ##s
# 2                for , ##veni con ##ent              rear , , for ##s
# 3                     ada ##ent . ##s ,                to and - ##s ,
# 4                      , ada ada - rear              ##s , end - rear
# 5              ##ptive end ada cruise ,         more ##veni for , con
# 6                 ##s con end for ##ent               , - con end ##s
# 7              ##s con for ##veni ##ent    collision rear end for ##s
# 8                    for , rear ##s ada             - to end rear ##s
# 9               dense cruise - rear ada            con ##s - end rear
# 10                cruise ada - rear end              , rear - ##s end
# 11        cruise ##ptive ada cruise ada      ##s ada ##veni ##ent con
# 12              cruise end rear ada ada             ada for and end ,
# 13       cruise ##ptive end ##ptive ada               ##s . end ada ,
# 14          cruise rear ada ##ptive end            ada ada rear end ,
# 15             ##ptive ada end rear ada              ##s , - rear end
# 16          cruise ##ptive ada rear end            , rear end ada ##s
# 17         ada ##s cruise collision end          ##veni , ##s for con
# 18       control ##ptive cruise ada ada     ada more ##veni ##ent con
# 19             ada ##ptive rear ada end           end for ##s ada con
# 20        cruise ada ##ptive cruise ada      ##veni ada end ##ent con
# 21         cruise end cruise con ##veni     more for ##ent ##veni con
# 22        ada cruise ##veni ada control    more ##ent for control con
# 23       control ada ##ptive cruise ada      ##veni ##ent ada con ada
# 24       ##ptive prevent end cruise for        cruise ##s con ada for
# 25               rear ##ptive ada - end            , con rear end ada
# 26              ada rear end cruise ada            , ##s ada end rear
# 27       ##ptive rear cruise ada cruise       for cruise ada end rear
# 28         cruise ada ##veni cruise con      ##veni ada ##ent con for
# 29     ##ptive ##ent ada control cruise             ada con , ada for
# 30  ##veni control cruise ##ent control  control ##veni ##ent con for
# 31   control ##veni control makes ##ent       con , control ##ent for
# 32         con ada ##veni control ##ent     more ##veni con ##ent for
# 33         cruise makes ada ##ptive ada     con ##ptive ada ##ent ada
# 34            cruise ada ##veni for con           con ada ##ent , for
# 35        ##ptive ##veni ada con cruise        end cruise ada con for
# 36             ##ptive end ada cruise ,         more ##veni for , con
#
#                              head_11
# 0                 end - to prevent ,
# 1                con ##ent - end ##s
# 2           ##veni for ##s con ##ent
# 3                 - rear , ##s ##ent
# 4                 ada ##s end rear -
# 5          , ##ptive ##ptive ada ada
# 6                ##ent con - ##s end
# 7           ##veni ##ent for con ##s
# 8               - ##ent end rear ##s
# 9                 ada ##s end rear -
# 10          collision rear ##s - end
# 11              ##ent rear ##s - end
# 12                ada ##s - rear end
# 13             ada ##ptive - end ada
# 14                ada - rear ada end
# 15                ada ##s - end rear
# 16             - ada end ada ##ptive
# 17         end ##s ada ##ptive ##ent
# 18               rear to ##ent end -
# 19         ##ptive ##s - end ##ptive
# 20             cruise ##s rear - end
# 21          end con ##s ##veni ##ent
# 22           to con ##s ##veni ##ent
# 23     ##ptive ##ent ##ptive ada ada
# 24      ada rear ada ##ptive ##ptive
# 25                for ##s end rear -
# 26                ##s ada rear end -
# 27             ##ptive end - ada ada
# 28     ##ent ##ptive ada ##ptive ada
# 29     ##ptive ##ent ##ptive ada ada
# 30  con control ##veni control ##ent
# 31          con ada ada ##veni ##ent
# 32           for makes ##ent ada ada
# 33     ##ptive ada ##ptive ada ##ent
# 34     ##ptive ##ptive ##ent ada ada
# 35      ##ptive ada ##veni con ##ent
# 36         , ##ptive ##ptive ada ada

# %%
en_ret_docs[0]
# Out:
# 'Adaptive cruise control makes riding more convenient for the rider, especially in dense traffic, and could help to prevent rear-end collisions.'

# %%
en = "Adaptive cruise control makes riding more convenient for the rider, especially in dense traffic, and could help to prevent rear-end collisions."
de = "Die adaptive Geschwindigkeitsregelung macht das Fahren für den Fahrer insbesondere bei dichtem Verkehr komfortabler und könnte helfen, Auffahrunfälle zu vermeiden."

# %%
query, doc = en, de
inputs, output = get_output(sent_1=query, sent_2=doc)
tokens, query_tokens = get_tokens(inputs)
df = show_attention(output=output, tokens=tokens, layer=11, only_query_tokens=False, query_tokens=query_tokens)
df
# Out:
# There are 70 tokens: ['[CLS]', 'ada', '##ptive', 'cruise', 'control', 'makes', 'riding', 'more', 'con', '##veni', '##ent', 'for', 'the', 'rider', ',', 'especially', 'in', 'dense', 'traffic', ',', 'and', 'could', 'help', 'to', 'prevent', 'rear', '-', 'end', 'collision', '##s', '.', '[SEP]', 'die', 'ada', '##ptive', 'geschwindigkeit', '##sr', '##ege', '##lung', 'macht', 'das', 'fahren', 'fur', 'den', 'fahrer', 'insbesondere', 'bei', 'dicht', '##em', 'verkehr', 'kom', '##fort', '##able', '##r', 'und', 'konnte', 'hel', '##fen', ',', 'auf', '##fa', '##hru', '##n', '##falle', 'zu', 'ver', '##meid', '##en', '.', '[SEP]']
# Attention of Layer: 11
#               token                                          head_0  \
# 0             [CLS]           macht insbesondere ##fort dicht dense
# 1               ada            bei dicht insbesondere konnte ##meid
# 2           ##ptive              bei auf ##meid insbesondere konnte
# 3            cruise        especially dicht auf insbesondere konnte
# 4           control                       kom ##meid dicht rear auf
# 5             makes                        bei und konnte dicht auf
# 6            riding               insbesondere dicht ##meid kom ver
# 7              more                         ver rear bei ##meid auf
# 8               con                konnte bei rear insbesondere auf
# 9            ##veni              dicht konnte rear insbesondere auf
# 10            ##ent               insbesondere ##hru dicht ##fa auf
# 11              for              insbesondere dicht konnte rear auf
# 12              the               macht insbesondere ver auf konnte
# 13            rider                        dicht auf ##meid kom ver
# 14                ,               ##ptive auf ##falle konnte ##meid
# 15       especially                          ada kom auf ##meid ver
# 16               in                          und ##r ver kom konnte
# 17            dense                      hel ver ##fen macht konnte
# 18          traffic                       ada hel ##fort konnte kom
# 19                ,                 ##meid konnte ada ##ptive macht
# 20              and  verkehr insbesondere dicht geschwindigkeit auf
# 21            could               bei geschwindigkeit ada auf dicht
# 22             help           ada geschwindigkeit ##ptive auf dicht
# 23               to         insbesondere ##ptive dicht macht ##lung
# 24          prevent         ##lung macht dicht ##ptive insbesondere
# 25             rear            konnte kom ##lung insbesondere macht
# 26                -            konnte ##lung kom macht insbesondere
# 27              end            ##lung kom konnte macht insbesondere
# 28        collision               fur konnte kom insbesondere macht
# 29              ##s               ##fort fur macht kom insbesondere
# 30                .              kom ada ##ptive macht insbesondere
# 31            [SEP]                              ##en . ##n ##s ver
# 32              die                           - to end prevent rear
# 33              ada               help rear more prevent especially
# 34          ##ptive               dense and rear prevent especially
# 35  geschwindigkeit               end dense rear prevent especially
# 36             ##sr               end rear dense prevent especially
# 37            ##ege               dense end especially rear prevent
# 38           ##lung               especially dense end prevent rear
# 39            macht                 and especially prevent end rear
# 40              das           collision especially prevent rear end
# 41           fahren               dense prevent rear end especially
# 42              fur           especially collision prevent rear end
# 43              den           collision especially prevent rear end
# 44           fahrer                    ##ptive con rear end prevent
# 45     insbesondere               especially makes prevent end rear
# 46              bei                         and more con help makes
# 47            dicht               especially prevent and makes help
# 48             ##em           prevent control makes especially help
# 49          verkehr                 ##ptive prevent help more makes
# 50              kom                 prevent and end rear especially
# 51           ##fort             traffic prevent especially end rear
# 52           ##able             traffic prevent especially end rear
# 53              ##r           collision especially prevent rear end
# 54              und                    in especially dense end rear
# 55           konnte                       traffic dense in end rear
# 56              hel               traffic rear end dense especially
# 57            ##fen                    rear dense end in especially
# 58                ,                 end in ##ptive dense especially
# 59              auf                  con more especially help makes
# 60             ##fa                could makes help more especially
# 61            ##hru                  could con help more especially
# 62              ##n           control ##ptive makes more especially
# 63          ##falle                 con ##ptive and more especially
# 64               zu            ada makes control ##ptive especially
# 65              ver                in ##ptive dense more especially
# 66           ##meid               control dense and more especially
# 67             ##en                 end in dense ##ptive especially
# 68                .              ##ent con makes ##ptive especially
# 69            [SEP]                              ##en . ##n ##s ver
#
#                                     head_1  \
# 0            ##hru ##meid ##falle ##fa end
# 1                ##fa ##hru zu ##falle ##n
# 2                  ##falle ##s ##en zu ##n
# 3                   ##fen ##fa zu ##n ##en
# 4                      ##em auf , ##n ##fa
# 5                  ##em auf ##hru ##n ##fa
# 6                    - ##hru ##fa ##en ##n
# 7                     ##s ##hru - ##fa ##n
# 8                   zu ##hru ##em ##n ##fa
# 9                    ##hru ##em auf ##n zu
# 10                   ##em auf ver ##n ##fa
# 11                    ##ege ver - ##fa ##n
# 12                 ##meid - ver ##fa ##ege
# 13                      , ##en zu ##fa ##n
# 14                 ver ##hru ##sr ##fa ##n
# 15               ##ege ##sr ##hru ##fa ##n
# 16            ##lung ##fort ##sr hel ##ege
# 17                   ##ege ##en zu ##n und
# 18                      ##sr ##en , zu den
# 19            ver ##ptive ##fort ##sr ##fa
# 20              ##ege dicht ##hru auf ##fa
# 21                    auf ##n - ##hru ##fa
# 22                   - ##hru ##em ##fa ##n
# 23         ##ptive ada ##lung ##fort ##ege
# 24                ##em ##lung den die ##sr
# 25                und ##r die ##ege ##lung
# 26              ##r macht den ##ege ##lung
# 27                ##r macht ##lung die den
# 28                     das und ##r den die
# 29   macht geschwindigkeit ##ptive ada den
# 30        ##veni ##fort ##ptive ##ege ##sr
# 31                     ##s ##fa ##en , ##n
# 32                end ##s collision ##fa -
# 33                   end collision , , ##s
# 34                          to and , , ##s
# 35                          and - , to ##s
# 36        collision dense prevent rear end
# 37                       the end rear to -
# 38                      to ##fa rear end -
# 39                     rear ##s end ##fa -
# 40                end ##fa collision ##s -
# 41                        to end and ##s -
# 42                ##fa end collision ##s -
# 43             traffic collision ##s end -
# 44                     ##veni to and ##s -
# 45                      ##s end ##fa ##n -
# 46              ada - collision ##s ##veni
# 47                         for , , ##s and
# 48          help ada ##veni especially for
# 49               and ##ptive ##veni for to
# 50                            , - in , ##s
# 51                          , , ##n to ##s
# 52                       in ##n the - ##fa
# 53               end collision rear - ##fa
# 54                    ada dense end - ##fa
# 55                         ##s end for , -
# 56                     , traffic end - ##s
# 57                  cruise traffic , end -
# 58  collision ##veni ##ege traffic control
# 59          and makes ##ent ##veni control
# 60                   , makes and ##r ##ent
# 61              especially ada and makes ,
# 62             more makes , ada especially
# 63                    for makes and the in
# 64         ##ptive dense ##fort ##veni ada
# 65                         ##s the , for ,
# 66                          and in , the ,
# 67        ada control dense cruise ##ptive
# 68          ##sr ##ptive ##ege ##fort ##fa
# 69                     ##s ##fa ##en , ##n
#
#                                  head_2  \
# 0              ##able ##em ##hru - ##fa
# 1                 ##n ##fa ##s ##hru zu
# 2                        ##s ##n zu , ,
# 3                        , , ##s , ##fa
# 4                  ##n ##hru auf , ##fa
# 5                  - ##n auf ##hru ##fa
# 6               ##en ver ##hru ##fa ##n
# 7               ##meid ##hru - ##n ##fa
# 8                  ##en - zu ##hru ##fa
# 9                    to ##fa ##n zu auf
# 10                   - ver auf ##n ##fa
# 11              ##sr auf ##hru ##n ##fa
# 12       ##ege ##meid hel ##falle ##hru
# 13                   ##hru - , ##n ##fa
# 14               auf ver ##n ##hru ##fa
# 15                ##hru ##sr - ##n ##fa
# 16             ##fort ##ege ver ##n hel
# 17                  , und ##en ##n ##sr
# 18                   ##sr zu den ##fa ,
# 19     ##sr ##fort ##ptive ##ptive ##fa
# 20           ##ege auf ##hru dicht ##fa
# 21                 auf - ##n ##hru ##fa
# 22              auf ##em ##n ##hru ##fa
# 23      dicht ##sr ##ptive ##fort ##ege
# 24                , ##ege ##sr den ##fa
# 25              und , ##sr ##lung ##ege
# 26  macht insbesondere ##r ##lung ##ege
# 27             den macht ##ege , ##lung
# 28                   ##sr ##r den die ,
# 29         ##ptive ##ege ##fort den ada
# 30       ##sr ##fa ##fort ##ege ##ptive
# 31                 ##s ##hru - ##en ##n
# 32             rear end ##s collision -
# 33                       to , for , ##s
# 34                         to . ##s , ,
# 35                        - , , and ##s
# 36             especially dense , for ,
# 37                   ##s ##fa rear to -
# 38                   in end rear - ##fa
# 39                  rear ##s end - ##fa
# 40         especially rider ##hru - ##s
# 41                      to , ##s ##fa -
# 42                  rear end ##fa ##s -
# 43    ##falle prevent end collision ##s
# 44                 prevent to end ##s -
# 45             collision the end ##fa -
# 46  ##ptive help ##ent collision ##veni
# 47                       - to . and ##s
# 48          especially ada , rider help
# 49             for and to makes ##ptive
# 50                      in ##fa , ##s -
# 51                      , rear to ##s -
# 52                   in - rear ##n ##fa
# 53            collision end rear ##fa -
# 54           - ##ptive dicht dense ##fa
# 55                   ##n end ##s ##fa -
# 56                     ##s end - , ##fa
# 57                 dense in ##fa rear ,
# 58   ##veni traffic rider control ##ege
# 59          makes ##lung ##veni ##ent ,
# 60        and ##ent ##lung , especially
# 61                  and for ada makes ,
# 62     for more ##able especially ##ent
# 63                   makes in the , ada
# 64      ##fort ##ege ##ptive ada ##veni
# 65                     and , in ##ent ,
# 66                    ##ent the , , and
# 67       ##veni traffic con rider dense
# 68     ##ptive ##fa ##veni ##ege ##fort
# 69                 ##s ##hru - ##en ##n
#
#                                     head_3                            head_4  \
# 0            [CLS] ##able ##ege kom ##fort             ##en ##ege , das ##fa
# 1               ##s ##hru ##falle ##em ##n            ##em ##hru ##n ##en zu
# 2                ##s , ##n ##falle verkehr                 zu und . ##en ##n
# 3                        ##s ##fa ##n zu ,                ##n ##fa zu , ##en
# 4                     ada ##hru , auf ##fa                ##hru - , auf ##fa
# 5                  ##em auf ##n ##fa ##hru        ##falle auf ##fa ##hru ##n
# 6                    - ##sr ##hru ##em ##n          ##en ##hru ##fa ##sr ##n
# 7                    ##em ##hru - ##n ##fa           auf ##sr ##hru ##fa ##n
# 8              verkehr auf ##hru ##em ##fa              ##hru zu ##fa ##en ,
# 9                . bei verkehr ##em fahrer               ##fa auf , ##hru zu
# 10                   ada ver rear auf ##fa               ##n auf zu ver ##fa
# 11          ##falle ##n ##ptive ##hru ##fa     ##ptive ##fort ##n ##sr ##hru
# 12         ##fort ##ege ##falle ##hru ##fa      ##able ##sr kom ##fort ##ege
# 13                   ##em - ##hru ##fa ##n        ##en ##fort ##hru ##fa ##n
# 14         ada ##fort ##ptive ##fa ##ptive    ##sr ##ptive ##fort ##hru ##fa
# 15                 ##hru ##r ##em ##fa ##n           ##hru das ##sr ##fa ##n
# 16        ##ptive ##able ##ege ##lung ##sr         hel ##ege ##sr kom ##fort
# 17                  ##r ##n ##ege ada ##sr           ##n ##en und ##ege ##sr
# 18                ver macht ##sr ada ##ege             ver , den ##fort ##sr
# 19  geschwindigkeit ##ege ##sr ##ptive ada      ada ##ege ##fort ##ptive ver
# 20  geschwindigkeit ada ##ptive ##hru ##fa         ##ege kom ##n ##fort ##fa
# 21                ##ptive ##n - ##hru ##fa      ##falle ##ege ##hru ##fa ##n
# 22                 auf ##em ##fa ##n ##hru           auf ##sr ##fa ##hru ##n
# 23           ada ##lung ##sr ##ege ##ptive      ##able ##sr kom ##fort ##ege
# 24           ##ptive ##ege ##lung ##sr ada           ##fort kom und ##r ##sr
# 25            ##able ##ege ##sr ##r ##lung         die ##r ##lung ##ege ##sr
# 26           fahrer ##r macht ##ege ##lung       die ##r fahrer ##lung ##ege
# 27             konnte ##r ##lung macht ada          den und ##r ##lung ##ege
# 28                     und ##r die den ada             ##r ##ptive die , den
# 29            macht fahrer ##ptive den ada        ##ptive den kom ##fort ada
# 30           ##sr ##fort ##ege ##ptive ada      con ##ege ##sr ##veni ##fort
# 31                    prevent . ada to ##n                    ##n , ##s to -
# 32                    ##hru ##n ##fa - ##s        ##veni collision ##s ##n -
# 33                       ##ent - , end ##s                 could and , , ##s
# 34                      to . traffic , ##s                     . for ##s , ,
# 35                          - , ##s and to                     , , and ##s ,
# 36                   rear dense - ada ##fa               prevent , dense , -
# 37      rear ##fa especially dense traffic                    and end , to -
# 38                   dense end rear - ##fa                in end rear ##fa -
# 39                   rear end - ##hru ##fa          collision end ##fa ##s -
# 40              ##s ##ent especially - ada       con ##veni ##s - especially
# 41                          , ada - to and                      to . and - ,
# 42                  end - ada ##ptive ##fa                   end , ##s ada -
# 43                      ada - ##fa ##s end       traffic collision end - ##s
# 44                        ada to end ##s -               and ##veni to ##s -
# 45                      end the ##n ##fa -                end ##s ##n ##fa -
# 46                  - ##s ada ##ent ##veni   cruise control con ##ent ##veni
# 47                        and . the to ##s       control ##ent makes and ##s
# 48              rider control ver help ada       help control ##veni con ada
# 49                the ##ptive makes ada to      ada con makes ##ptive ##veni
# 50                    end ##s ##hru - ##fa                to and ##hru - ##s
# 51                       traffic , , ##s .                     , , and , ##s
# 52            in prevent traffic rear ##fa                  to in and rear -
# 53                    end ##s ##hru - ##fa             ##hru ##fa ada rear -
# 54               cruise ada ##ptive ##fa -      ##veni dense con ##ptive ada
# 55                traffic ##hru end ##fa -          ##n ##fa collision ##s -
# 56              ##s the traffic ##em ##hru                 ##hru end , - ##s
# 57                      in , the traffic ,                    in con , - ada
# 58           ada ##lung ##sr control ##ege  ##ege ##ptive con ##veni control
# 59          ada ##ent makes ##lung control             , and , control makes
# 60    macht insbesondere konnte ##lung ##r       ##r especially more ##ent ,
# 61              ada und konnte makes macht               could ##r , makes ,
# 62       ##ptive help makes ada especially      makes could especially ada ,
# 63                    and ada to makes the           , con ##ptive ada makes
# 64       control ##fort ##veni ##ptive ada     cruise con ##ptive ##veni ada
# 65                          ##em - ##s , ,               and ##s ##ptive , ,
# 66                  especially and the , ,            ##ent more control , ,
# 67            dense con ##ptive cruise ada     control con cruise ##veni ada
# 68       control ##veni ##ptive ##fort ada       - ##ptive con ##fort ##veni
# 69                    prevent . ada to ##n                    ##n , ##s to -
#
#                                 head_5                                head_6  \
# 0                for to con the ##veni                         - ada the , ,
# 1              ##falle ##fa ##n zu ##s            ##n verkehr ##en konnte zu
# 2                       . , zu ##s ##n                  ##s ##fa , konnte zu
# 3                   , ##s ##en ##fa zu                konnte ##en , ##fen zu
# 4                     ##n , - auf ##fa               end dicht auf rear ##fa
# 5                 auf ##n ##hru - ##fa        auf ##falle ##hru verkehr ##fa
# 6                      zu ##fa . - ##n                 ver ##fen zu ##n ##en
# 7                 end ##hru ##n - ##fa                 rear - ##hru end ##fa
# 8                    end zu auf - ##fa                  zu ##fa end rear auf
# 9                , ##hru rear auf ##fa                   end - rear ##fa auf
# 10                  ##n den - auf ##fa                    zu ##em - auf ##fa
# 11                 auf zu - ##hru ##fa                 zu ##en ##falle end -
# 12                ##en - zu ##hru ##fa                 zu ##falle , ##n ##en
# 13                   ver ##fa - zu ##n            ##meid ##n ##en ##fort ver
# 14         ##ptive ver ##sr ##hru ##fa             , ##falle ##able ##en ##n
# 15                 zu - ##hru ##n ##fa            ver ##en ##ege ##n ##falle
# 16           ##n ##fa ##fort ##r ##ege               ##able hel ##fen ##en ,
# 17                ##sr ##r ##en zu und                 zu ver konnte ##ege ,
# 18           ##en ##able ver ##veni zu             fur konnte ##fen , ##fort
# 19               ver ada ##sr ada ##fa           ##veni ##ent for ##able fur
# 20                end auf - ##hru ##fa          ##en ##able ##fa verkehr fur
# 21                the ##hru den - ##fa  verkehr geschwindigkeit ##fa for fur
# 22             auf ##n ##hru ##em ##fa    ##fa ##falle traffic dicht verkehr
# 23       die ##lung ##fa ##ptive ##ege              ##r fur ##ent con ##able
# 24              den ##ege ##r ##em die              kom ##r ##ege ##lung fur
# 25        ##able ##sr ##ege ##r ##lung            makes ##ent ##lung con for
# 26  insbesondere ##sr ##lung ##ege ##r              ##r more for makes macht
# 27      konnte ##fort ##lung ##ege ##r                more kom macht ada die
# 28                 und das ##r den die                ##ege ##r more ada die
# 29        fahrer den ada ##ptive ##ege           ##ege ##fort ##r fur ##able
# 30     ##veni ##ptive ada ##ptive ##fa                , ##veni for ##ent con
# 31                konnte ##en zu , ##n                    and und ##s ##en ,
# 32                      , , ##s ##fa -                 ##en ##hru end zu ##s
# 33                      and to , , ##s                     makes and to zu ,
# 34                      to and ##s , ,                 , especially ##s , to
# 35                      the to , and ,                 and to , especially ,
# 36                      the rear , - ,               especially in , to rear
# 37                      , end , rear -                       , - to end rear
# 38                  end to ##fa rear -               prevent ##fa - rear end
# 39                 ##s rear end ##fa -                  ##hru rear ##s - end
# 40                      ##fa , , ##s -                       , zu ##en ##s -
# 41                      - the and , to                end and - , especially
# 42                      rear ada , , -                        , ##s to end -
# 43                        , ##s to , -                      ##n to ##s - end
# 44                 end ada ##veni to -             prevent ##s end con ##ent
# 45                 end rear the ##fa -             ##ent end - collision ##s
# 46              , ##ent and con ##veni                  to con ##ent makes ,
# 47                   ##s makes , , and                   help and , makes to
# 48                    con to and for ,                    fur makes , for to
# 49               the ada and ##veni to                   , more to ada makes
# 50                      ##fa , the , -                       end - to rear ,
# 51                       to rear - , ,               - especially , end rear
# 52                       , in , ##fa -                    to ##fa end rear -
# 53                  in rear end ##fa -                 rear ##hru ##fa end -
# 54                 ada end rear - ##fa                       fur end , for -
# 55                    for ##fa , the -                        , in fur , for
# 56                       , the end - ,                for , cruise , traffic
# 57                    the end rear , -                   ##s traffic - , for
# 58              control ##veni and , ,                  ##veni con ##ent , ,
# 59                makes , ##veni , and              ##ent ##r more makes for
# 60                 , makes ##ent and ,       especially ##r more macht makes
# 61                 the ada makes , and         for makes especially die more
# 62        makes rider and , especially                 makes das for the die
# 63                 , makes ada and the   ##ptive ##fort die especially ##ege
# 64           ##fort , ##ege ##veni ada                   ##lung , in fur for
# 65                     and die the , ,          traffic , the especially for
# 66                     die the and , ,         more and makes for especially
# 67             and ##ptive ada rider ,                 in especially , for ,
# 68         , ada ##ptive ##fort ##veni             , ##ege ##lung fur ##able
# 69                konnte ##en zu , ##n                    and und ##s ##en ,
#
#                                  head_7  \
# 0               - con ##ent end prevent
# 1          ##fa ##fort ##fen ##meid ver
# 2          ##hru ##fort ##fa ver ##meid
# 3                 auf , ##en ver ##meid
# 4          ##fa ##en prevent ver ##meid
# 5             ##hru auf ##meid ver ##fa
# 6            ##en ##hru ##fa ##meid ver
# 7             ##fen ##hru dicht auf ver
# 8             auf ##meid ##en ##fen ver
# 9           dicht ver ##en ##meid ##fen
# 10         auf verkehr ver ##meid dicht
# 11           ##fen dicht auf ##meid ver
# 12             auf dicht kom ver ##meid
# 13            dicht auf ##en ##meid ver
# 14              ##meid , ##en ##fen ver
# 15         ##fort ##fen ##en ##meid ver
# 16          konnte ##meid hel ##fen ver
# 17             hel ##fort ver kom ##ege
# 18            ##fort ##en hel ver ##fen
# 19          ##fort kom ##ent ver ##able
# 20          dicht ##meid ver kom ##fort
# 21             kom ##fort auf ver dicht
# 22         verkehr ada kom ##fort dicht
# 23           con ##ege macht kom ##fort
# 24        ##lung ##ege ##fort kom macht
# 25        ##veni macht kom ##ege ##fort
# 26          ##veni ##r kom macht ##fort
# 27       ##able ##lung kom macht ##fort
# 28          ##r ##able macht kom ##fort
# 29          macht ##r ##able kom ##fort
# 30           kom makes ##veni ##ent con
# 31                       the in ##s , -
# 32               ##s - rear end prevent
# 33             to help end rear prevent
# 34             help to end rear prevent
# 35             help to rear end prevent
# 36              to ##s rear end prevent
# 37            ##s help rear end prevent
# 38              ##s to rear end prevent
# 39         collision - prevent rear end
# 40               - ##s prevent rear end
# 41                to - rear end prevent
# 42               ##s - rear prevent end
# 43           ##s ##ent help end prevent
# 44              ##s to rear end prevent
# 45               ##s - end rear prevent
# 46           end ##ent help con prevent
# 47        ##veni con ##ent prevent help
# 48        ##veni prevent help con ##ent
# 49            ##ent con to help prevent
# 50               ##s - rear prevent end
# 51               ##s - rear prevent end
# 52            ##en ##s rear end prevent
# 53       ##s collision prevent rear end
# 54        ##ent rear con ##veni traffic
# 55            rear ##veni end ##ent con
# 56         ##ptive end ##ent ##veni con
# 57         end ##veni ##ent traffic con
# 58  ##ptive especially ##veni con ##ent
# 59           makes for ##veni con ##ent
# 60        ##able makes ##veni con ##ent
# 61          ##veni help makes con ##ent
# 62          help ##veni makes con ##ent
# 63         help ##able ##veni con ##ent
# 64           makes for ##veni con ##ent
# 65    especially makes ##veni ##ent con
# 66          help makes ##veni ##ent con
# 67           for makes ##veni con ##ent
# 68             makes , ##veni ##ent con
# 69                       the in ##s , -
#
#                                               head_8  \
# 0                         macht ##ege konnte hel ver
# 1               ##fort ver insbesondere dicht ##meid
# 2                  [CLS] ##fort verkehr dicht ##meid
# 3                     [CLS] verkehr ver dicht ##meid
# 4                    fahren auf verkehr dicht ##meid
# 5                       verkehr auf ver dicht ##meid
# 6         verkehr ##hru dicht geschwindigkeit ##meid
# 7               ver ##hru geschwindigkeit auf ##meid
# 8             fahren dicht [CLS] insbesondere ##meid
# 9        especially ##fort [CLS] insbesondere ##meid
# 10                   auf verkehr fahren dicht ##meid
# 11                      verkehr ver ##hru auf ##meid
# 12                         hel ##en ##hru ver ##meid
# 13                        dicht ver ##hru auf ##meid
# 14                            ada hel ver auf ##meid
# 15                         ##fa ver ##hru auf ##meid
# 16                            ada hel ver auf ##meid
# 17            ##hru auf geschwindigkeit dicht ##meid
# 18                          hel ver auf dicht ##meid
# 19                            kom hel ver auf ##meid
# 20                       ##hru ##fort ver auf ##meid
# 21       fahren dicht verkehr geschwindigkeit ##meid
# 22       dicht verkehr fahren geschwindigkeit ##meid
# 23       ##fort verkehr geschwindigkeit dicht ##meid
# 24    geschwindigkeit ada ##meid fahren insbesondere
# 25    ada ##fort geschwindigkeit insbesondere fahren
# 26  fahren geschwindigkeit insbesondere dicht ##meid
# 27  fahren macht geschwindigkeit ##meid insbesondere
# 28  insbesondere fahren dicht geschwindigkeit ##meid
# 29        geschwindigkeit fahren ##fort dicht ##meid
# 30             hel ##meid fahren ada geschwindigkeit
# 31                        ##meid ##ent ##ege ver hel
# 32                       end ver help ##meid prevent
# 33                 con makes especially help prevent
# 34                con collision ##ptive prevent help
# 35                collision makes could prevent help
# 36                     con makes ##meid prevent help
# 37                     , end especially help prevent
# 38                   , collision ##meid help prevent
# 39                    end ada collision help prevent
# 40                   ##ptive help end ##meid prevent
# 41                   makes could ##meid prevent help
# 42                ada ##ptive collision help prevent
# 43                 end collision ##meid help prevent
# 44             especially ada collision prevent help
# 45                 collision cruise ada prevent help
# 46                    ##ptive makes ada prevent help
# 47                        ada makes con help prevent
# 48                    ##veni ##meid con prevent help
# 49                      makes could con prevent help
# 50               con especially ##ptive prevent help
# 51               ada ##ptive help especially prevent
# 52                   help end prevent cruise ##ptive
# 53                    ada collision end prevent help
# 54                 collision help ada cruise prevent
# 55                   ada ##ptive prevent cruise help
# 56                ada ##ptive cruise help especially
# 57                cruise ##ptive especially ada help
# 58                           kom ada hel ##fort help
# 59                   could especially con makes help
# 60                 con especially ##ptive makes help
# 61                   ##ent con makes especially help
# 62                 con prevent makes especially help
# 63               ##ptive ada especially prevent help
# 64                   ada prevent ##ptive cruise help
# 65                ##ptive ada cruise especially help
# 66                 makes con prevent especially help
# 67                     makes ##fort ##ptive ada help
# 68                         help , cruise ##ptive ada
# 69                        ##meid ##ent ##ege ver hel
#
#                                      head_9  \
# 0                rider ##veni ##ent for the
# 1                     . prevent , ##r ##ent
# 2                    ##meid ##s prevent , .
# 3                      rear prevent ##s , .
# 4                - ##fa ##meid prevent rear
# 5                     - end ##fa ##hru rear
# 6                  rear ##hru ##sr ada ##fa
# 7                   ##hru end ##fa rear ada
# 8                 ##meid . rear end prevent
# 9                      . , end prevent rear
# 10             ##meid prevent auf ##fa rear
# 11                 auf end ##meid ##fa rear
# 12            ##sr ##hru prevent ver ##meid
# 13                   ##sr . macht ##ege ada
# 14                      end , rear ada ##fa
# 15                  kom ##fa ada ##sr ##ege
# 16                ##r ##sr kom ##lung ##ege
# 17           ##fort macht ##sr ##lung ##ege
# 18                   kom ##sr con ##ege ada
# 19            ##ptive ada ##ptive prevent ,
# 20                  - ##meid ##hru end ##fa
# 21                  rear end ada ##hru ##fa
# 22                   ada auf ##n ##hru ##fa
# 23                   ada kom con ##sr ##ege
# 24              con ##sr macht ##ege ##lung
# 25            ##veni con ##ent ##ege ##lung
# 26            macht ##able ##lung ##ent ##r
# 27            con macht ##veni ##ege ##lung
# 28              kom ##ptive ada makes macht
# 29             ##fort con macht ##ptive kom
# 30  con ##ptive geschwindigkeit ##ptive ada
# 31                 prevent rear end , makes
# 32             - rear end collision prevent
# 33                end ##s for prevent ##ent
# 34         collision rear ##s ##ent prevent
# 35               ##s , traffic rear prevent
# 36                 end - dense rear prevent
# 37                    to end - rear prevent
# 38                  ##fa end prevent - rear
# 39                  prevent ##fa end - rear
# 40           traffic end rear ##s collision
# 41                   end ada - rear prevent
# 42            traffic end prevent ##fa rear
# 43       prevent traffic collision end rear
# 44               end for prevent ##veni con
# 45                  con ada ##veni end rear
# 46            help control ##ent con ##veni
# 47            ##veni help ##ent con prevent
# 48            con ##ent ##veni help prevent
# 49             ##ptive makes ##veni ada con
# 50               rear - prevent traffic end
# 51             traffic prevent ##s rear end
# 52                  prevent ##fa - end rear
# 53                    ##hru end ##fa - rear
# 54              prevent rear ##ptive - ##fa
# 55                      rear ##fa end ada -
# 56         cruise dense ##ptive end traffic
# 57          ##ptive rear control cruise con
# 58          ##ent dense control con traffic
# 59          ##lung ##veni con control ##ent
# 60           for makes control ##ent ##lung
# 61                 ada help con makes ##ent
# 62           ##lung ##ptive for makes ##ent
# 63             ##veni con ada ##ptive makes
# 64              con makes ada ##ent ##ptive
# 65        traffic for control ##ptive ##ent
# 66          con ##ptive makes ##ent control
# 67          ##sr ##ptive cruise con control
# 68         cruise con ##ent control ##ptive
# 69                       . rear end , makes
#
#                                head_10                          head_11
# 0                 ada ada ver ##meid .           ##hru , die ##fen ##en
# 1                     ##r zu ##n , ##s              ##hru - ##n end ##s
# 2                         , , zu , ##s                ##ent . ##n , ##s
# 3                    ver und ##en , zu                   - rear . ##s ,
# 4                  . ##fa end auf rear              auf ##fa end - rear
# 5                    zu , auf ##n ##fa             rear - ##hru ##s end
# 6                    and , zu ver ##en              ##n ##hru ##s - end
# 7                    ##n zu ##en ver ,                 ##s . - rear end
# 8                         . zu , auf ,                 ##s . - rear end
# 9                     . rear end auf ,                   , . - end rear
# 10                  rear zu , ##fa auf             auf - ##hru end rear
# 11                 zu ada auf ##en ver           ada - ##ptive rear end
# 12               . prevent ##s zu ##en                - . end ##ent ##s
# 13                ##able , zu ##en ver          ##n prevent ##ent end -
# 14                   und ver zu ##en ,                 rear ##s . - end
# 15              ##able ##sr ##en ver ,              ##n ##s ##hru - end
# 16            ##en ##able more fur ##r      ##r ##lung con ##veni ##ent
# 17                fur ##r zu ##en ##sr       con ##ege ##lung ##r ##ent
# 18                 ada ##en ##sr ##r ,        con ada ##ptive ada ##ent
# 19                  fur und ada ##en ,     ada ada rear ##ptive ##ptive
# 20              ##en ##ptive auf , ada              ##fa ##s - rear end
# 21                end , ##hru ##fa auf             - ##n ##fa end ##hru
# 22    , geschwindigkeit ##hru ##fa auf             ##s ##fa - end ##hru
# 23  ##sr makes more insbesondere macht   ##ege control ##veni ##ent con
# 24         makes ##ptive ##lung , more      die ##lung ##veni con ##ent
# 25       ##ent control ##sr more makes  ##veni control con ##lung ##ent
# 26    and insbesondere ##r ##sr ##lung      ##able ##veni ##r con ##ent
# 27          ##ent con macht makes more     ##veni more ##ent con ##lung
# 28          con macht ##ent makes more        ##able die ##r more ##ent
# 29            ##r and macht makes more       more con ada ##ptive ##ent
# 30          makes for ##veni ##ent con    more ##ptive ##veni ##ent con
# 31               ##ege ##en and ##sr ,          auf ##en ##n ##fa ##ege
# 32              ##n ##hru end ##fa ##s             - ##s ##fa ##hru ##n
# 33                       . , - end ##s              ##hru ##n - end ##s
# 34                      - end to , ##s   traffic rear collision ##n ##s
# 35                    ##fa ##s . ver ,          , prevent rear ##s ##en
# 36                   . end rear ##fa .             auf rear - ##en ##fa
# 37                  auf ##s - rear end            rear ##hru ##fa end -
# 38                 auf ##fa - rear end            rear ##hru end ##fa -
# 39                 rear ##s ##fa - end             ##s ##fa end ##hru -
# 40                    , . ##en ##s ver          ##fa ##s ##en ##hru ##n
# 41               rear . ##meid ver ##s            ##fa end - ##hru ##en
# 42                 . ##meid , ##fa ver             end ##s ##fa - ##hru
# 43            ver ##meid prevent , ##s        ##en ##meid ##n ##s ##hru
# 44     ##ent ##able prevent ##meid ver           ##n ##en - prevent end
# 45               end ##fa ##meid , ver             ##s ##fa - ##hru end
# 46            for kom ##r ##able ##ent    ##s ##hru ##fort ##able ##ent
# 47                 ##ent ##r ver , ##s        ##s ##able ##en ##r ##ent
# 48              ##en ##ent ##ege ver ,       ##ege kom ##able ##r ##ent
# 49               ##ege could ada , ver      ##fen ##able ##ent ##en ver
# 50                      , . ##fa - end             ##fa ##s end - ##hru
# 51                    rear - . ##s end                - auf . ##s ##hru
# 52                    , - ##fa end auf            - ##fa ##hru auf rear
# 53                 auf - rear ##fa end             auf ##fa - end ##hru
# 54                  , ver ada auf ##fa             end - auf ##hru ##fa
# 55             rear end ##hru auf ##fa             ##n ##s - ##fa ##hru
# 56                 rear ##s , ##fa end           - dicht end ##fa ##hru
# 57               ##s end rear auf ##fa         auf ##n ##fa dicht ##hru
# 58     especially ##sr ##s ##ent ##ege  control ##sr ##ent ##lung ##ege
# 59        ##able makes ##ege ##r ##ent    ##able ##r ##ent ##ege ##lung
# 60            kom ##lung for ##ent ##r    ##able ##ege ##ent ##lung ##r
# 61             makes ##ent and for ##r       ##ent ##ege die ##lung ##r
# 62             makes ##ent for ##r and      ##lung ##able ##ent ##r die
# 63          ##able ##r ##ent makes and           ##able kom ada ##r die
# 64              , ##able kom ##r ##ege    ##ege ##lung ##able ##ent die
# 65                 ##r and , for ##ent      ##lung ##r ##able ##ent die
# 66             kom ##ent and ##r makes         kom die ##able ##ent ##r
# 67                     ada , and for ,       kom die dicht ##fort ##ege
# 68             ##fort ##sr fur for kom    ##sr ##lung ##able kom ##fort
# 69               ##ege ##en and ##sr ,          auf ##en ##n ##fa ##ege

# %%
query, doc = 'adaptive cruise control', en_ret_docs[0]
inputs, output = get_output(sent_1=query, sent_2=doc)
tokens, query_tokens, doc_tokens = get_tokens(inputs)
df = show_attention(output=output, tokens=tokens, layer=11, only_query_tokens=False, query_tokens=query_tokens)
df
# Out:
# Attention of Layer: 11
#          token                                head_0  \
# 0        [CLS]  ada control ##ptive especially dense
# 1          ada        dense more end especially rear
# 2      ##ptive     dense prevent end especially rear
# 3       cruise     prevent dense end rear especially
# 4      control           - especially dense rear end
# 5        [SEP]               help prevent rear . ##s
# 6          ada          help dense prevent more rear
# 7      ##ptive          in dense especially end rear
# 8       cruise     prevent end especially dense rear
# 9      control          especially in end dense rear
# 10       makes                   in - dense end rear
# 11      riding            dense ##ptive rear ada end
# 12        more            ada cruise cruise rear end
# 13         con            ada cruise cruise rear end
# 14      ##veni      dense cruise especially end rear
# 15       ##ent                 ada - cruise rear end
# 16         for               ada ada cruise rear end
# 17         the           ##ptive ada cruise rear end
# 18       rider                rear dense ada ada end
# 19           ,              ada rear ##ptive ada end
# 20  especially               cruise ada ada end rear
# 21          in              ##ptive more end ada ada
# 22       dense            help control ada ada makes
# 23     traffic         makes control ##ptive ada ada
# 24           ,           ##ptive end ##ptive ada ada
# 25         and            cruise ada cruise rear end
# 26       could          cruise cruise dense rear end
# 27        help             cruise ada rear end dense
# 28          to               cruise end in ada dense
# 29     prevent     ##ptive more ada dense especially
# 30        rear     ada especially control more makes
# 31           -     more control ada especially makes
# 32         end         con ada more especially makes
# 33   collision         ada more makes especially ada
# 34         ##s       for ##ptive more ada especially
# 35           .               for ada con ##ptive ada
# 36       [SEP]               help prevent rear . ##s
#
#                                     head_1  \
# 0              ##ptive ##s collision - end
# 1                           to the , - ##s
# 2                          and ##s the , ,
# 3                           to , and - ##s
# 4                          ##s , to rear -
# 5                              . , ##s , -
# 6                            - , the , ##s
# 7                          the for , , ##s
# 8                           - , to and ##s
# 9                          , rear ##s to -
# 10                collision rear ##s end -
# 11                         , ada and ##s -
# 12                         the , ada ##s -
# 13                         , the and ##s -
# 14                           ##s , in to -
# 15                   the cruise rear ada -
# 16               ##ptive ##s ada ##ptive -
# 17               ##s ##ptive ##ptive ada -
# 18                        ada to and ##s -
# 19            cruise ada ##ptive ##ptive -
# 20                      rear the ##s end -
# 21                ##veni ##ptive ada ##s -
# 22                          to , - ##s and
# 23                     ##veni and ada - to
# 24       cruise cruise ##ptive ada ##ptive
# 25                collision rear end ada -
# 26                 collision ##s ada end -
# 27                         , ##s end ada -
# 28                cruise control - ada ada
# 29                     , ##ptive ##s the -
# 30           control makes control and ##s
# 31  ##ent especially control control makes
# 32            control control and to makes
# 33                    ##ptive , the to and
# 34             makes cruise ada cruise ada
# 35                ##s ##ptive ada ##veni -
# 36                             . , ##s , -
#
#                                   head_2                              head_3  \
# 0                 ##veni for end ##ent -          ##ent ada ada ##veni [CLS]
# 1                        end , for - ##s                   - ##ent , ##s end
# 2                         to ##s for , ,                  traffic to con , ,
# 3                          and ##s , - ,                      ##s , and to ,
# 4                         end , , rear -                     , to end rear -
# 5                        , ##ent ##s , -               ##ptive ada - ada con
# 6                        - for end , ##s                 control , - ##s end
# 7                        and ##s for , ,                      end to ##s , ,
# 8                          - and , ##s ,                      . ##s to and ,
# 9                          in , rear , -                     rear and , to -
# 10                      , rear ##s end -              ##ptive rear ##s end -
# 11                  ##ptive rear , ada -           ##ptive ada - ##ptive ada
# 12                   end , ##ptive ##s -               end ada ##ptive ada -
# 13                     and . , ##ptive -           ##ptive end - ##ptive ada
# 14                       , rear ##s to -                     in rear , end .
# 15                ##ptive ada rear ada -               end cruise rear - ada
# 16               ##ptive , ada ##ptive -           end ##ptive - ada ##ptive
# 17                   ada end ##ent ##s -        cruise ##ptive - ada ##ptive
# 18                         and , , ##s -                    to end ##s - ada
# 19          cruise end - ##ptive ##ptive        - cruise ##ptive ada ##ptive
# 20                 the end ##s ##ptive -         cruise ##ptive ada cruise -
# 21            ##veni ##ent ada ##ptive -        ##veni control ##ptive ada -
# 22                         . , and ##s -                   and ada , ada ##s
# 23                  ada ##ptive to ada -          to ##ptive ##ptive ada ada
# 24  cruise cruise ##veni ##ptive ##ptive   control cruise cruise ##ptive ada
# 25          end cruise ##ptive ##ptive -            end cruise ##ptive ada -
# 26              collision rear end ##s -              rear ada ##ptive end -
# 27                  rear , ##ptive ada -            cruise ##ptive ada end -
# 28        ##ptive ##veni ##ptive ada ada  control cruise control ada ##ptive
# 29                 ##ptive ##ptive , , -               ##ptive con ada , ada
# 30               , control , control and         ##ent , ada control control
# 31    ada control makes especially ##ent     ada could control makes control
# 32                   makes and , ada ada            control to makes ada ada
# 33                       ada ada , and ,                   and the ada , ada
# 34         cruise ##ptive ##veni ada ada            makes cruise the ada ada
# 35            con ##ent - ##ptive ##veni         cruise - ##veni ##ptive ada
# 36                       , ##ent ##s , -               ##ptive ada - ada con
#
#                             head_4                         head_5  \
# 0                  the , and ada .            con ##veni - to the
# 1               end ##ent , to ##s               for the , to ##s
# 2                for and ##ent , ,                 and to ##s , ,
# 3                 , - ##veni ##s ,                 . ##s and to ,
# 4            end ##veni con rear -                the , rear to -
# 5                 , [CLS] to ##s -                 . and to ##s ,
# 6              traffic , and , ##s               and the to ##s ,
# 7                  ##s and for , ,                 to the and , ,
# 8                    and . , ##s ,               the ##s and to ,
# 9                   , , rear ada -                 and to , the -
# 10        collision rear ##s end -               , ##s rear end -
# 11           , ada ##ptive [CLS] -                 ada , the to -
# 12              ada rear end ##s -                end , ada ##s -
# 13             , and ##ptive - ##s                , and the ada -
# 14                  - ##s . and to                rear the to , -
# 15        collision ada ada rear -              in rear the ada -
# 16           end ada ##ptive ada -            ##s , ##ptive ada -
# 17        ##veni ##ptive ##s ada -             to , ##ptive ada -
# 18              , ##ptive to ##s -               end and to ada -
# 19       ada end ##ptive - ##ptive          rear to - ##ptive ada
# 20        ada to ##ptive ##ptive -           ##ptive end to the -
# 21            ada ada con - ##veni            and to con ##veni -
# 22               [CLS] ##s . , and                 ##s . to , and
# 23         - ##veni to ##ptive ada          the and ##veni to ada
# 24    ada rear ##ptive ada ##ptive         con - rear ##ptive ada
# 25        ##ptive ##veni con - ada         end ##ptive rear ada -
# 26         collision ada end ##s -             rear the end ada -
# 27       ##ptive ##ptive ada ada -           cruise end ada the -
# 28            con ada - ##veni ada      ##ptive ada - ##ptive ada
# 29             ##ptive ada and , -                - , the and ada
# 30           control , and , ##ent  ada control and control makes
# 31  help control makes rider ##ent        makes , ada control and
# 32             makes ada , ada and         could to ada and makes
# 33           the ##ptive ada and ,          ada makes ada and the
# 34          cruise the con ada ada     especially the for ada ada
# 35          cruise to con ##veni -       ##veni con - ##ptive ada
# 36                , [CLS] to ##s -                 . and to ##s ,
#
#                             head_6                          head_7  \
# 0                      . ada , , -       ##ptive con - end prevent
# 1                and help , to for     prevent end ##veni con rear
# 2              ##ent more to , for              , for rear end con
# 3                help and the to ,          prevent con , rear end
# 4                for to rear - end       ##ent ##veni con rear end
# 5                    and , - ##s ,               dense , ##s end -
# 6                and more to for ,          - con prevent end rear
# 7                ##s , more to for        for prevent rear con end
# 8         especially more the , to          , ##s prevent rear end
# 9              more ada - rear end        con ##s prevent rear end
# 10        collision - rear ##s end          ##s prevent - rear end
# 11             the con end ##ent ,    collision , prevent rear end
# 12           collision - end , ##s          - ##s prevent rear end
# 13              ada in rear to end         - help prevent end rear
# 14              end , rear ada ada         help - prevent end rear
# 15               to rear end ##s -  collision ##s prevent rear end
# 16                  , to end ##s -  collision ##s prevent rear end
# 17             cruise to end - ##s       help con rear prevent end
# 18           the end con ##ent for          ##s - prevent rear end
# 19              cruise , end ##s -           - to end prevent rear
# 20      collision end cruise - ##s          ##s - prevent rear end
# 21         ##veni con ##s ##ent to     end ##veni help prevent con
# 22              ada for , makes to     cruise ##ent end ##veni con
# 23           con ##ent ada more to        , prevent ##veni con end
# 24             ##s con ##ent - for    for ##ptive ##veni con ##ent
# 25                 end , for - ##s       ##ent rear end con ##veni
# 26               end rear in - for              ##s con - rear end
# 27         for end cruise cruise -   cruise ada ##ptive ##veni con
# 28         in con for ##ent cruise    ##ptive ##ent for ##veni con
# 29               ##ent ada , , for      for makes ##ent ##veni con
# 30        more control , makes for      makes for ##ent con ##veni
# 31       for control ada ada makes      for makes con ##ent ##veni
# 32          more for ada makes ada      makes for con ##veni ##ent
# 33          ada for makes more ada      makes for ##ent ##veni con
# 34  ##ptive more ##ptive makes ada    control for ##veni ##ent con
# 35                 - con ##s for ,          , for ##ent ##veni con
# 36                   and , - ##s ,               dense , ##s end -
#
#                                    head_8  \
# 0             could help ada ##veni makes
# 1        rear ##veni , especially prevent
# 2            cruise rear ##veni prevent ,
# 3             dense cruise prevent rear ,
# 4           especially , end rear prevent
# 5                  ada con ada end ##veni
# 6       ##veni collision ada help prevent
# 7         , ##veni collision prevent help
# 8       ada cruise collision prevent help
# 9            end , collision prevent help
# 10        rear end prevent collision help
# 11                   , end ada help [CLS]
# 12             ada ada control end cruise
# 13      ##ptive ada help [CLS] especially
# 14            , [CLS] help end especially
# 15        especially ##ptive help ada end
# 16         ada collision help prevent end
# 17         collision ada help end prevent
# 18                 ada end , prevent help
# 19            ada ##veni end rear prevent
# 20  especially collision end help prevent
# 21              rear end ada help prevent
# 22        especially [CLS] , help prevent
# 23               end prevent [CLS] , help
# 24      collision ada rear ##veni prevent
# 25            end rear cruise ada prevent
# 26           rear prevent cruise end help
# 27     especially [CLS] cruise ada cruise
# 28      cruise control ##ptive ada cruise
# 29      help prevent [CLS] ada especially
# 30      ada especially cruise makes [CLS]
# 31   cruise ##veni [CLS] especially makes
# 32         , help cruise makes especially
# 33       especially cruise cruise , [CLS]
# 34     control , cruise cruise especially
# 35                  , con rear ##veni ada
# 36                 ada con ada end ##veni
#
#                                  head_9                       head_10  \
# 0                [CLS] for - end cruise          ada ##s ada rear end
# 1             help ##veni con for ##ent               - , con for ##s
# 2                for , ##veni con ##ent              rear , , for ##s
# 3                     ada ##ent . ##s ,                to and - ##s ,
# 4                      , ada ada - rear              ##s , end - rear
# 5              ##ptive end ada cruise ,         more ##veni for , con
# 6                 ##s con end for ##ent               , - con end ##s
# 7              ##s con for ##veni ##ent    collision rear end for ##s
# 8                    for , rear ##s ada             - to end rear ##s
# 9               dense cruise - rear ada            con ##s - end rear
# 10                cruise ada - rear end              , rear - ##s end
# 11        cruise ##ptive ada cruise ada      ##s ada ##veni ##ent con
# 12              cruise end rear ada ada             ada for and end ,
# 13       cruise ##ptive end ##ptive ada               ##s . end ada ,
# 14          cruise rear ada ##ptive end            ada ada rear end ,
# 15             ##ptive ada end rear ada              ##s , - rear end
# 16          cruise ##ptive ada rear end            , rear end ada ##s
# 17         ada ##s cruise collision end          ##veni , ##s for con
# 18       control ##ptive cruise ada ada     ada more ##veni ##ent con
# 19             ada ##ptive rear ada end           end for ##s ada con
# 20        cruise ada ##ptive cruise ada      ##veni ada end ##ent con
# 21         cruise end cruise con ##veni     more for ##ent ##veni con
# 22        ada cruise ##veni ada control    more ##ent for control con
# 23       control ada ##ptive cruise ada      ##veni ##ent ada con ada
# 24       ##ptive prevent end cruise for        cruise ##s con ada for
# 25               rear ##ptive ada - end            , con rear end ada
# 26              ada rear end cruise ada            , ##s ada end rear
# 27       ##ptive rear cruise ada cruise       for cruise ada end rear
# 28         cruise ada ##veni cruise con      ##veni ada ##ent con for
# 29     ##ptive ##ent ada control cruise             ada con , ada for
# 30  ##veni control cruise ##ent control  control ##veni ##ent con for
# 31   control ##veni control makes ##ent       con , control ##ent for
# 32         con ada ##veni control ##ent     more ##veni con ##ent for
# 33         cruise makes ada ##ptive ada     con ##ptive ada ##ent ada
# 34            cruise ada ##veni for con           con ada ##ent , for
# 35        ##ptive ##veni ada con cruise        end cruise ada con for
# 36             ##ptive end ada cruise ,         more ##veni for , con
#
#                              head_11
# 0                 end - to prevent ,
# 1                con ##ent - end ##s
# 2           ##veni for ##s con ##ent
# 3                 - rear , ##s ##ent
# 4                 ada ##s end rear -
# 5          , ##ptive ##ptive ada ada
# 6                ##ent con - ##s end
# 7           ##veni ##ent for con ##s
# 8               - ##ent end rear ##s
# 9                 ada ##s end rear -
# 10          collision rear ##s - end
# 11              ##ent rear ##s - end
# 12                ada ##s - rear end
# 13             ada ##ptive - end ada
# 14                ada - rear ada end
# 15                ada ##s - end rear
# 16             - ada end ada ##ptive
# 17         end ##s ada ##ptive ##ent
# 18               rear to ##ent end -
# 19         ##ptive ##s - end ##ptive
# 20             cruise ##s rear - end
# 21          end con ##s ##veni ##ent
# 22           to con ##s ##veni ##ent
# 23     ##ptive ##ent ##ptive ada ada
# 24      ada rear ada ##ptive ##ptive
# 25                for ##s end rear -
# 26                ##s ada rear end -
# 27             ##ptive end - ada ada
# 28     ##ent ##ptive ada ##ptive ada
# 29     ##ptive ##ent ##ptive ada ada
# 30  con control ##veni control ##ent
# 31          con ada ada ##veni ##ent
# 32           for makes ##ent ada ada
# 33     ##ptive ada ##ptive ada ##ent
# 34     ##ptive ##ptive ##ent ada ada
# 35      ##ptive ada ##veni con ##ent
# 36         , ##ptive ##ptive ada ada

# %%
query, doc = 'adaptive cruise control', en_ret_docs[0]
inputs, output = get_output(sent_1=query, sent_2=doc)
tokens, query_tokens, doc_tokens = get_tokens(inputs)
df = show_attention(output=output, tokens=tokens, layer=10, only_query_tokens=True, query_tokens=doc_tokens)
df
# Out:
# Attention of Layer: 10
#          token                              head_0  \
# 0        [CLS]              rear ##s - end prevent
# 1          ada          dense collision - rear end
# 2      ##ptive         collision - traffic end ##s
# 3       cruise                 ##s and , traffic ,
# 4      control                       , in - and to
# 5        [SEP]        and prevent ##veni ##ent end
# 6          ada          dense collision - end rear
# 7      ##ptive         traffic - collision end ##s
# 8       cruise        rear , traffic ##s collision
# 9      control                 - , prevent to rear
# 10       makes               in prevent end - rear
# 11      riding          ada collision - ##veni ##s
# 12        more            collision ada - ada rear
# 13         con                   rear in - ada ada
# 14      ##veni        collision traffic end in ##s
# 15       ##ent                 the ##s end rear in
# 16         for              ada end prevent - rear
# 17         the             cruise and ada rear end
# 18       rider      - traffic ##veni collision ##s
# 19           ,                prevent to - ada ada
# 20  especially     ##ptive rear cruise ##ptive end
# 21          in            rear - cruise cruise end
# 22       dense  ##veni control ##s ##ent collision
# 23     traffic                ada ada ##ent to and
# 24           ,              makes cruise - ada ada
# 25         and              ##ptive rear ada - end
# 26       could                  ada ada end rear -
# 27        help          ##ptive rear dense ada ada
# 28          to                - cruise ada ada end
# 29     prevent     dense cruise ada cruise control
# 30        rear     ##ent cruise ada control ##veni
# 31           -       ##ent control the control and
# 32         end     makes and control control ##ent
# 33   collision          ##veni makes control ##ent
# 34         ##s                     ##ent , the and
# 35           .         cruise makes cruise ada ada
# 36       [SEP]        and prevent ##veni ##ent end
#
#                         head_1                     head_2  \
# 0    ##ptive collision ##s ada    to prevent ##veni end -
# 1               for to , - ##s        , control end ##s -
# 2                end . ##s , -             to , ##s - for
# 3          prevent , end ##s -          ##veni for to - ,
# 4               - rear , end .          to for end rear -
# 5               con to - ##s ,          rear ##s end to -
# 6                end for - ##s    makes prevent ##s end -
# 7              ada for end ##s  ##ent collision for end -
# 8          ##ptive end ada ##s       and ada prevent to -
# 9          ##ptive end ##s ada      ##veni end for rear -
# 10            . ##s rear end -       dense ##s rear end -
# 11      - ##veni ##ent ##s con      and ##ent ##veni - to
# 12                    . , to -           , rear ##s end -
# 13                to ##s , . -          to ada rear end -
# 14                   , ##s . -          end and rear in -
# 15            end . rear ##s -     ##ptive ada end rear -
# 16              and end to . -         ada rear ##s end -
# 17                to ##s , . -     prevent rear end ##s -
# 18              con , to - ##s        ##s to ada ##veni -
# 19                , ##s . to -         rear end ##s ada -
# 20                . , to ##s -        to for cruise end -
# 21          ##ent and ##s - to     ##ent con ##s ##veni -
# 22        ##ent , and makes to          ada help , and to
# 23  prevent ##ent con makes to        - ada and ##veni to
# 24                , . ada - to         rear end ##s ada -
# 25      prevent rear ##s end -   collision rear ##s end -
# 26            , ##s end rear -       ##s dense rear end -
# 27                  rear . , -        ada , ##ptive ##s -
# 28                to makes - ,            ada ##s con , -
# 29           con ##ent makes ,     con and ##veni ##ent ,
# 30        con , to ##ent makes  ##ent control makes and ,
# 31            ##ent to , makes     , control to makes and
# 32        and ##ent , to makes       ##ent , makes to and
# 33      and con ##ent to makes         for , and ##ent to
# 34              makes ada , to         for to ada con ada
# 35                  the . to ,       for ada ##veni con -
# 36              con to - ##s ,          rear ##s end to -
#
#                           head_3                              head_4  \
# 0                   , and ##s to        collision end - prevent rear
# 1            prevent end , - ##s                  for in traffic , ,
# 2                , for - end ##s            for , end and especially
# 3               rear , - end ##s            rear in especially , and
# 4               , - rear end ##s                 in dense rear - end
# 5                  ada , , ##s -                   rear ada end - to
# 6                 end to ##s - ,                prevent ##s , rear ,
# 7                 , - end to ##s            and - for end especially
# 8              rear - ##s end to           - especially end and rear
# 9              to - end rear ##s         especially dense - rear end
# 10        prevent rear - end ##s                   ##s rear end in -
# 11              ##ent to - , ##s                     , ada ada - end
# 12              , end ##s rear -                    ada in and end -
# 13              end rear , ##s -          ada cruise rear cruise end
# 14              end , ##s rear -            end cruise cruise - rear
# 15              , ##s rear end -          rear ##ptive ##ptive - end
# 16                     , . ##s -                cruise ada ada - end
# 17                to end , ##s -                ada ##ptive ##s in -
# 18              ##ent , - ##s to          dense rear ada ##ptive end
# 19                      , to . -             ##s cruise end cruise -
# 20          prevent to end ##s -                ada and ##veni - end
# 21                  . and , to -             and help makes to ##ent
# 22      control ada ##s to makes                for makes to ada ada
# 23  makes control to ##ptive ada            rear ada end ##ptive ada
# 24                   . - ##s end            rear cruise cruise end -
# 25              , rear end - ##s                dense rear the - end
# 26        prevent rear end - ##s                  dense the in end -
# 27           ##ptive , ada - ##s  cruise collision traffic ada dense
# 28             , - ##s the ##ent        the traffic control cruise ,
# 29            in for ##ent the ,         , control control and makes
# 30         , for the ##ent makes                   makes for ada and
# 31         and , for ##ent makes                     for ada ada and
# 32       and the for ##ent makes           especially ada to and ada
# 33         the , makes for ##ent    dense ##ptive especially ada ada
# 34         for the , ada ##ptive       ##ent ada ada ##ptive ##ptive
# 35               for ##ent con ,               to ##ent - ##veni end
# 36                 ada , , ##s -                    ada ada end - to
#
#                             head_5                     head_6  \
# 0           ##ptive ada - rear end       - prevent ##s to con
# 1         collision rear ##s end -             - to , end ##s
# 2       cruise - collision end ##s      , prevent ##s for end
# 3           ada to - collision ##s             to ##s end - ,
# 4                to ##s rear end -            , to rear - end
# 5                to con rear end -             for ##s , to -
# 6         collision ##s rear - end       prevent - to end ##s
# 7         rear - collision ##s end     to prevent con end for
# 8   the collision prevent ##s rear             ##s , - end to
# 9            to prevent - end rear             ##s , - end to
# 10              ada ##s - rear end   collision rear ##s end -
# 11                ada to end - ##s         prevent , ##s - to
# 12              rear ada end ##s -     collision to end - ##s
# 13              ada rear ada end -              in . to ##s -
# 14          ##ptive rear - ##s end              . to in ##s -
# 15               - to ada rear end       prevent to ##s end -
# 16              end ada rear ada -        end . prevent - ##s
# 17          ##ptive end ada rear -       to - ##s prevent end
# 18           ##ptive ada end - ##s             end , ##s to -
# 19              ada rear end ada -       prevent - end to ##s
# 20           ##s ##ptive end ada -       prevent to - end ##s
# 21              ada rear ##s - end       ##s prevent - end to
# 22          ada ##ent help ada ##s      ##s and help makes to
# 23           ##ent help ada to ada            . help - and to
# 24           end - ##ptive ada ada      ada ##veni ##s to end
# 25          rear ##ptive end ada -           to for ##s end -
# 26              - ##s ada rear end           in for ##s end -
# 27              - rear ##s ada end           for in end - ##s
# 28              rear - ##s ada end        - ##veni ##s for in
# 29       ##ptive ada con ##ent ada            the to , in for
# 30    control ##veni ##ent ada con     for ##ent makes con to
# 31   the for control ##ent control  help ##veni con makes for
# 32       con for control the ##ent       in ##veni con to for
# 33            to the ##ent for ada    for to ##veni ##ent con
# 34              con in the for ada      ada ##veni to con for
# 35          ##ptive rear ada - ada          ##s for to in con
# 36               to con rear end -             for ##s , to -
#
#                              head_7                             head_8  \
# 0             prevent to rear end -  riding ada control ##ptive cruise
# 1                   , for end - ##s       , control ada ##ptive cruise
# 2         collision prevent , - ##s       , control ##ptive cruise ada
# 3                      , to - , ##s    more control cruise ##ptive ada
# 4                 to ##s end rear -     control con ##ptive cruise ada
# 5             ##veni ##s to ada for                     to end , ##s -
# 6                   , for - end ##s           ##s cruise - end prevent
# 7       - prevent collision for ##s        collision ada - end prevent
# 8                     for , - , ##s               and - to end prevent
# 9                 ##s in end - rear               con to - prevent end
# 10         collision ##s rear end -             , collision rear - end
# 11                     to - ##s and             especially ada , end -
# 12              end collision - ##s            help cruise ##ptive ada
# 13                and the end ##s -                 cruise , end - ada
# 14                rear in end ##s -              cruise ada rear - end
# 15               the end rear ##s -                    end , ada - ada
# 16            ##ptive ada end ##s -                 end rear ada - ada
# 17            prevent and end ##s -           end ##ptive cruise - ada
# 18             and to prevent - ##s                ##ptive end ada , -
# 19            ada end ##ptive - ##s       - control cruise ##ptive ada
# 20           to collision end ##s -             , - cruise control ada
# 21          end control ##ent - ##s          - help cruise ##ptive ada
# 22     makes control to ##s control               , end ##veni - makes
# 23             ada and makes ada to            to makes ada con ##veni
# 24             end ##s ada cruise -      to control cruise ##ptive ada
# 25            cruise rear ##s end -              cruise rear - end ada
# 26         rear collision ##s - end              ##veni rear ada - end
# 27                in rear ##s end -           end ##ptive cruise - ada
# 28         control cruise end ##s -           ##ptive - ada cruise ada
# 29          the control ##ptive ada     control end ##ptive cruise ada
# 30  for makes control ##ent control      makes ##ptive more cruise ada
# 31  control for ##ent makes control     control ##veni more cruise ada
# 32        and ada for control makes  ##veni control ##ptive cruise ada
# 33          makes ada ada for ##ent         con more ##veni cruise ada
# 34          control the for ada ada      ##ptive con cruise ##veni ada
# 35         con ##veni control ##s -      con ##veni ##ptive cruise ada
# 36            ##veni ##s to ada for                     to end , ##s -
#
#                                   head_9                           head_10  \
# 0                   rear ##s collision .          especially help to and .
# 1                  to ##veni ##ptive ada          collision rear ##s end -
# 2                ##ptive ada ##ptive ada          collision ##s rear - end
# 3                ##ptive ada ##ptive ada          collision ##s rear - end
# 4                control ada ##ptive ada          ##s collision - rear end
# 5                    the ##s in end rear                for rear ##s - end
# 6      rear ada prevent cruise collision       prevent collision ##s end -
# 7   prevent ##ptive ada cruise collision          ##s collision rear - end
# 8   prevent ##ptive cruise ada collision           riding dense - rear end
# 9       ##s cruise ##ptive ada collision      collision prevent - rear end
# 10            cruise control ##ptive ada      prevent collision - rear end
# 11  collision control ##ptive cruise ada                  ##s rear , end -
# 12            cruise control ##ptive ada          ##s collision - rear end
# 13            control cruise ##ptive ada            ##ptive rear ada end -
# 14            control ##ptive cruise ada          collision ##s rear - end
# 15            control cruise ##ptive ada          collision ##s - rear end
# 16          - control ##ptive cruise ada                rear ada - ##s end
# 17            control cruise ##ptive ada                ada rear - end ##s
# 18            control cruise ##ptive ada             cruise ##s rear - end
# 19        ada cruise control ##ptive ada                    - rear ##s end
# 20            cruise control ##ptive ada          collision ##s - rear end
# 21        control ##ptive ada cruise ada             rear - cruise ##s end
# 22        ada control ##ptive cruise ada      ##ptive control cruise - end
# 23          - control ##ptive ada cruise    control ##ptive ada cruise end
# 24                  cruise - ##ptive ada                  cruise - end ##s
# 25                     ada prevent end -                ada rear - ##s end
# 26            control cruise ##ptive ada          ##ptive dense rear - end
# 27            control ##ptive cruise ada          - cruise end ##ptive ada
# 28                . ada ##ptive ##veni -        control cruise ada ##ptive
# 29            control ##ptive ada cruise      dense ada ##ptive cruise ada
# 30     control cruise ##ptive ada cruise         ##ent ada control ##ptive
# 31              - end ##ptive ada cruise   ##ent makes ada control ##ptive
# 32     ##ptive cruise ##ptive ada cruise     ada ##ent control for ##ptive
# 33           - cruise ##ptive ada cruise  ##ent cruise control ada ##ptive
# 34           - ##veni ##ptive ada cruise    the cruise control ada ##ptive
# 35                     , ##ptive ada ada                 ##s ##ent the for
# 36                   the ##s in end rear                for rear ##s - end
#
#                         head_11
# 0              ##s con to end -
# 1   and - prevent collision ##s
# 2       end for - collision ##s
# 3           end prevent , - ##s
# 4              , rear ##s end -
# 5       ##ent end prevent ##s -
# 6         , and - collision ##s
# 7       and end - collision ##s
# 8               and , end ##s -
# 9      collision rear ##s end -
# 10     collision rear ##s - end
# 11          prevent , end - ##s
# 12        , collision end ##s -
# 13             , rear end ##s -
# 14             , rear and ##s -
# 15     collision rear ##s end -
# 16          , prevent end ##s -
# 17      ##ent - prevent ##s end
# 18         prevent to end ##s -
# 19             rear , end ##s -
# 20   cruise collision end ##s -
# 21       con ##veni ##ent ##s -
# 22          makes - the and ##s
# 23         prevent to ##s and -
# 24           ada rear end ##s -
# 25         dense rear end ##s -
# 26   dense collision rear ##s -
# 27        rear ada cruise - ada
# 28         end ##s cruise ada -
# 29          the ##ent , and for
# 30        , the makes for ##ent
# 31        ##ent , makes for and
# 32        makes , the ##ent for
# 33          con , and for ##ent
# 34       for , ##veni ##ent con
# 35                , con , for -
# 36      ##ent end prevent ##s -

# %%
df[:6].to_csv('dummy.csv')

# %%
import numpy as np
def get_attended_tokens(output, tokens, query_tokens, layer=11):
    metrics = []
    num_heads = 12
    doc_start_ind = tokens.index('[SEP]') + 1
    for ind, token in enumerate(tokens):
        if ind < doc_start_ind:
            continue
        attended_tokens = []
        for head in range(num_heads):
            attention = output.attentions[layer][0][head][ind]
            # indices = np.argsort(attention.cpu().numpy())[::-1][-1:]
            indices = np.argsort(attention.cpu().numpy())[::-1][-len(query_tokens):]
            attended = [tokens[idx] for idx in indices if tokens[idx] in query_tokens]
            m = get_metrics(query_tokens, attended)
            metrics.append( 
                {
                'prec': m['prec'],
                'recall': m['recall'],
                'token': tokens[ind],
                'head': head
                }
            )
            attended_tokens.extend(attended)
        attended_tokens = list(set(attended_tokens)) 
    return attended_tokens, metrics

# %%
def get_metrics(query_tokens, attended_tokens):
    tp, fp, tn, fn = 0, 0, 0, 0
    for token in query_tokens:
        if token in attended_tokens:
            tp += 1
        else:
            fn += 1
            
    for token in attended_tokens:
        if token not in query_tokens:
            fp += 1
        
    prec, recall = 0, 0
    if tp + fp:
        prec = tp / (tp + fp)
    if tp + fn:
        recall = tp / (tp + fn)
    
    metrics = {
        'prec': prec,
        'recall': recall
    }
    return metrics

# %%
from collections import Counter
def show_scores(docs):
    layer_counts = []
    head_counts = []
    for idx, doc in enumerate(docs):
        query, doc = 'adaptive cruise control', doc
        inputs, output = get_output(sent_1=query, sent_2=doc)
        tokens, query_tokens, doc_tokens = get_tokens(inputs)
        macro = {'prec': 0, 'recall': 0}
        layer_count = []
        token_count = []
        head_count = []
        for layer in range(12):
            attended_tokens, metrics = get_attended_tokens(output, tokens, query_tokens, layer=layer)
            # metrics = get_metrics(query_tokens, attended_tokens)
            # macro['prec'] += metrics['prec']
            # macro['recall'] += metrics['recall']            
            for metric in metrics:
                macro['prec'] += metric['prec']
                macro['recall'] += metric['recall']
                if metric['prec'] == 1 and metric['recall'] == 1:
                    layer_count.append(layer)
                    token_count.append(metric['token'])
                    head_count.append(metric['head'])
            macro['prec'] /= len(metrics)
            macro['recall'] /= len(metrics)
            f_score = (macro['prec'] + macro['recall']) / 2
        

        macro['prec'] /= 12
        macro['recall'] /= 12
        macro['f_score'] = (macro['prec'] + macro['recall']) /2
        
        print(f"Retrieved at rank {idx}", macro['f_score'])
        print('Layer Count', Counter(layer_count).most_common(3))
        print('Token Count', Counter(token_count).most_common(3))
        print('Head Count', Counter(head_count).most_common(3))
        
        layer_counts.append(Counter(layer_count).most_common(1)[0])
        head_counts.append(Counter(head_count).most_common(1)[0])
        
    count = {
        'layer': Counter(layer_counts).most_common(1)[0],
        'head': Counter(head_counts).most_common(1)[0]
    }
        
    return count

# %%
query = 'adaptive cruise control'
en_ret_docs, de_ret_docs = retrieve(query)
print("EN")
count = show_scores(en_ret_docs)
print(f"Layer: {Counter(count['layer']).most_common(1)[0][0]}, Head: {Counter(count['head']).most_common(1)[0][0]}")
print("DE")
count = show_scores(de_ret_docs)
print(f"Layer: {Counter(count['layer']).most_common(1)[0][0]}, Head: {Counter(count['head']).most_common(1)[0][0]}")
# Out:
# 100%|██████████| 100/100 [00:01<00:00, 91.33it/s]
# 100%|██████████| 100/100 [00:01<00:00, 88.99it/s]
# EN
# Retrieved at rank 0 0.03549626239652399
# Layer Count [(2, 34), (7, 30), (8, 22)]
# Token Count [(',', 20), ('to', 13), ('dense', 12)]
# Head Count [(7, 39), (9, 30), (8, 14)]
# Retrieved at rank 1 0.01750645690259295
# Layer Count [(2, 65), (6, 13), (0, 10)]
# Token Count [('the', 8), ('in', 7), ('and', 6)]
# Head Count [(7, 67), (11, 11), (9, 9)]
# Retrieved at rank 2 0.014058686254523133
# Layer Count [(2, 90), (0, 13), (6, 9)]
# Token Count [('the', 14), ('.', 8), (',', 6)]
# Head Count [(7, 90), (9, 16), (11, 7)]
# Retrieved at rank 3 0.011839308072262631
# Layer Count [(2, 100), (0, 13), (6, 4)]
# Token Count [('the', 13), ('.', 12), ('and', 8)]
# Head Count [(7, 101), (9, 13), (11, 3)]
# Retrieved at rank 4 0.041019929976200555
# Layer Count [(7, 37), (2, 34), (5, 15)]
# Token Count [('to', 24), ('the', 23), ('preceding', 11)]
# Head Count [(7, 43), (9, 30), (3, 15)]
# Retrieved at rank 5 0.05170020736174518
# Layer Count [(2, 35), (7, 35), (5, 25)]
# Token Count [('the', 23), ('to', 18), ('flow', 16)]
# Head Count [(7, 34), (9, 27), (5, 18)]
# Retrieved at rank 6 0.015689896206310137
# Layer Count [(2, 97), (0, 12), (6, 12)]
# Token Count [('the', 20), ('and', 9), (',', 7)]
# Head Count [(7, 103), (9, 20), (11, 6)]
# Retrieved at rank 7 0.011411378725419618
# Layer Count [(2, 155), (0, 55), (1, 6)]
# Token Count [('the', 34), ('.', 17), (',', 11)]
# Head Count [(7, 159), (9, 52), (11, 6)]
# Retrieved at rank 8 0.03142804306686652
# Layer Count [(2, 35), (7, 16), (0, 9)]
# Token Count [(',', 9), ('the', 9), ('assist', 8)]
# Head Count [(7, 45), (9, 8), (4, 6)]
# Retrieved at rank 9 0.03341004449497604
# Layer Count [(2, 44), (9, 13), (10, 9)]
# Token Count [('the', 13), ('.', 7), ('desired', 6)]
# Head Count [(7, 45), (1, 13), (9, 12)]
# Layer: (2, 35), Head: (7, 45)
# DE
# Retrieved at rank 0 0.01629864371812341
# Layer Count [(2, 46), (0, 17), (6, 5)]
# Token Count [('die', 7), ('nach', 4), ('.', 4)]
# Head Count [(7, 45), (9, 16), (3, 5)]
# Retrieved at rank 1 0.007467034699334812
# Layer Count [(2, 74), (0, 22), (6, 2)]
# Token Count [('mit', 9), ('der', 7), ('dem', 5)]
# Head Count [(7, 74), (9, 21), (11, 2)]
# Retrieved at rank 2 0.024267765210594164
# Layer Count [(2, 48), (0, 18), (6, 5)]
# Token Count [('.', 6), ('und', 5), ('eine', 4)]
# Head Count [(7, 52), (9, 15), (11, 5)]
# Retrieved at rank 3 0.01733518844253975
# Layer Count [(2, 34), (0, 17), (7, 17)]
# Token Count [('und', 11), ('##ieren', 8), ('.', 7)]
# Head Count [(7, 36), (9, 22), (8, 10)]
# Retrieved at rank 4 0.030582643600831877
# Layer Count [(2, 24), (0, 14), (11, 8)]
# Token Count [('im', 5), ('##en', 5), ('die', 3)]
# Head Count [(7, 28), (9, 16), (11, 4)]
# Retrieved at rank 5 0.00392848358428158
# Layer Count [(2, 114), (0, 64), (9, 4)]
# Token Count [('.', 11), ('und', 10), ('die', 8)]
# Head Count [(7, 115), (9, 64), (1, 5)]
# Retrieved at rank 6 0.016744907958568787
# Layer Count [(2, 54), (0, 23), (6, 20)]
# Token Count [('.', 9), ('der', 8), ('und', 8)]
# Head Count [(7, 55), (9, 27), (11, 13)]
# Retrieved at rank 7 0.0022495918631598036
# Layer Count [(2, 106), (0, 36)]
# Token Count [(',', 10), ('„', 7), ('[UNK]', 6)]
# Head Count [(7, 106), (9, 34), (5, 1)]
# Retrieved at rank 8 0.021442522813691807
# Layer Count [(2, 34), (0, 8), (7, 7)]
# Token Count [('der', 6), ('die', 5), ('##en', 4)]
# Head Count [(7, 37), (9, 8), (3, 4)]
# Retrieved at rank 9 0.005867154639535973
# Layer Count [(2, 78), (0, 24)]
# Token Count [('die', 7), (',', 5), ('das', 4)]
# Head Count [(7, 78), (9, 22), (2, 1)]
# Layer: (2, 34), Head: (7, 45)

# %%
query = 'automatische notbremsung'
en_ret_docs, de_ret_docs = retrieve(query)
print("EN")
count = show_scores(en_ret_docs)
print(f"Layer: {Counter(count['layer']).most_common(1)[0][0]}, Head: {Counter(count['head']).most_common(1)[0][0]}")
print("DE")
count = show_scores(de_ret_docs)
print(f"Layer: {Counter(count['layer']).most_common(1)[0][0]}, Head: {Counter(count['head']).most_common(1)[0][0]}")
# Out:
# 100%|██████████| 100/100 [00:01<00:00, 94.08it/s]
# 100%|██████████| 100/100 [00:01<00:00, 91.26it/s]
# EN
# Retrieved at rank 0 0.044989418578295956
# Layer Count [(7, 42), (11, 34), (2, 29)]
# Token Count [('pe', 17), ('##rians', 14), ('.', 13)]
# Head Count [(7, 40), (10, 33), (2, 28)]
# Retrieved at rank 1 0.049159649762418496
# Layer Count [(7, 54), (2, 25), (8, 20)]
# Token Count [('and', 23), ('to', 15), ('-', 14)]
# Head Count [(9, 29), (7, 29), (3, 24)]
# Retrieved at rank 2 0.046987620874196376
# Layer Count [(7, 50), (2, 25), (11, 19)]
# Token Count [('and', 25), ('avoid', 13), ('the', 13)]
# Head Count [(7, 38), (3, 23), (9, 22)]
# Retrieved at rank 3 0.0031287534644060407
# Layer Count [(2, 177), (0, 73), (1, 5)]
# Token Count [('the', 36), ('to', 19), (',', 15)]
# Head Count [(7, 178), (9, 70), (0, 3)]
# Retrieved at rank 4 0.0053520807143551214
# Layer Count [(2, 164), (0, 62), (1, 5)]
# Token Count [('the', 22), (',', 14), ('.', 11)]
# Head Count [(7, 165), (9, 60), (10, 3)]
# Retrieved at rank 5 0.07128514758870197
# Layer Count [(7, 52), (8, 48), (11, 47)]
# Token Count [('##ing', 35), ('of', 29), ('live', 29)]
# Head Count [(9, 35), (3, 34), (7, 33)]
# Retrieved at rank 6 0.008290660129533575
# Layer Count [(2, 108), (0, 24), (1, 2)]
# Token Count [('the', 18), (',', 9), ('.', 9)]
# Head Count [(7, 110), (9, 23), (5, 1)]
# Retrieved at rank 7 0.05658501293147318
# Layer Count [(7, 51), (2, 26), (10, 25)]
# Token Count [('with', 21), ('avoid', 19), ('of', 17)]
# Head Count [(9, 42), (8, 32), (7, 26)]
# Retrieved at rank 8 0.05686874432122785
# Layer Count [(7, 55), (6, 32), (2, 24)]
# Token Count [('use', 20), ('for', 19), ('.', 19)]
# Head Count [(9, 33), (7, 27), (2, 22)]
# Retrieved at rank 9 0.022202852803840017
# Layer Count [(2, 90), (10, 49), (9, 15)]
# Token Count [('.', 19), ('a', 8), ('system', 5)]
# Head Count [(7, 91), (9, 49), (11, 13)]
# Layer: (7, 42), Head: (7, 40)
# DE
# Retrieved at rank 0 0.0026764930202149485
# Layer Count [(2, 72), (0, 45), (3, 9)]
# Token Count [('die', 12), ('das', 6), ('zu', 6)]
# Head Count [(7, 72), (9, 44), (2, 8)]
# Retrieved at rank 1 0.037479744767984824
# Layer Count [(7, 30), (2, 24), (11, 22)]
# Token Count [('beim', 12), ('fur', 10), ('ver', 10)]
# Head Count [(7, 38), (9, 23), (2, 22)]
# Retrieved at rank 2 0.010437664403034102
# Layer Count [(2, 77), (0, 30), (6, 5)]
# Token Count [('.', 10), (',', 4), ('die', 4)]
# Head Count [(7, 77), (9, 29), (11, 3)]
# Retrieved at rank 3 0.01251610109109705
# Layer Count [(2, 64), (0, 24), (10, 4)]
# Token Count [(',', 7), ('das', 6), ('des', 6)]
# Head Count [(7, 64), (9, 23), (10, 4)]
# Retrieved at rank 4 0.013121818110082352
# Layer Count [(2, 86), (0, 20), (6, 5)]
# Token Count [('die', 6), ('.', 5), ('der', 5)]
# Head Count [(7, 85), (9, 20), (8, 5)]
# Retrieved at rank 5 0.0109029654682743
# Layer Count [(2, 67), (0, 32), (10, 3)]
# Token Count [('zu', 8), (',', 6), ('die', 6)]
# Head Count [(7, 67), (9, 33), (10, 3)]
# Retrieved at rank 6 0.039809731592520964
# Layer Count [(7, 60), (8, 31), (2, 30)]
# Token Count [('zu', 30), ('##n', 20), ('oder', 17)]
# Head Count [(9, 45), (7, 39), (2, 38)]
# Retrieved at rank 7 0.010257500304423323
# Layer Count [(2, 60), (0, 22), (6, 9)]
# Token Count [(',', 5), ('.', 5), ('der', 5)]
# Head Count [(7, 61), (9, 21), (11, 10)]
# Retrieved at rank 8 0.040535359702122103
# Layer Count [(7, 75), (6, 38), (5, 30)]
# Token Count [('##en', 40), ('in', 20), ('fur', 18)]
# Head Count [(9, 44), (2, 34), (7, 32)]
# Retrieved at rank 9 0.0011594274473994278
# Layer Count [(2, 150), (0, 114), (3, 5)]
# Token Count [(',', 22), ('das', 16), ('die', 13)]
# Head Count [(7, 151), (9, 111), (2, 5)]
# Layer: (2, 72), Head: (7, 72)

# %%
query = 'driver assistance systems'
en_ret_docs, de_ret_docs = retrieve(query)
print("EN")
count = show_scores(en_ret_docs)
print(f"Layer: {Counter(count['layer']).most_common(1)[0][0]}, Head: {Counter(count['head']).most_common(1)[0][0]}")
print("DE")
count = show_scores(de_ret_docs)
print(f"Layer: {Counter(count['layer']).most_common(1)[0][0]}, Head: {Counter(count['head']).most_common(1)[0][0]}")
# Out:
# 100%|██████████| 100/100 [00:01<00:00, 94.00it/s]
# 100%|██████████| 100/100 [00:01<00:00, 89.74it/s]
# EN
# Retrieved at rank 0 0.03911295165067779
# Layer Count [(7, 39), (2, 29), (5, 26)]
# Token Count [('are', 22), ('before', 18), ('the', 18)]
# Head Count [(7, 34), (9, 27), (3, 26)]
# Retrieved at rank 1 0.06365590821295922
# Layer Count [(7, 48), (11, 39), (2, 31)]
# Token Count [('the', 64), ('.', 35), ('to', 31)]
# Head Count [(8, 49), (9, 40), (7, 28)]
# Retrieved at rank 2 0.027085338612843207
# Layer Count [(2, 44), (11, 14), (5, 13)]
# Token Count [('.', 9), ('and', 9), ('assist', 7)]
# Head Count [(7, 47), (8, 19), (9, 10)]
# Retrieved at rank 3 0.07263596986225701
# Layer Count [(10, 83), (11, 81), (7, 76)]
# Token Count [('all', 45), ('and', 44), ('protect', 44)]
# Head Count [(9, 53), (8, 53), (7, 50)]
# Retrieved at rank 4 0.0065648924725996765
# Layer Count [(2, 110), (0, 27), (6, 3)]
# Token Count [('the', 13), (',', 10), ('.', 10)]
# Head Count [(7, 111), (9, 25), (11, 3)]
# Retrieved at rank 5 0.05441390357695708
# Layer Count [(7, 43), (2, 36), (5, 32)]
# Token Count [('the', 30), ('.', 21), ('a', 19)]
# Head Count [(9, 38), (7, 29), (3, 29)]
# Retrieved at rank 6 0.012410218228690848
# Layer Count [(2, 119), (0, 66), (6, 5)]
# Token Count [('die', 11), ('der', 10), ('.', 9)]
# Head Count [(7, 120), (9, 65), (11, 3)]
# Retrieved at rank 7 0.025200327444959366
# Layer Count [(2, 42), (11, 24), (0, 16)]
# Token Count [('die', 8), ('audi', 6), ('-', 5)]
# Head Count [(7, 52), (9, 16), (8, 14)]
# Retrieved at rank 8 0.013251940599045558
# Layer Count [(2, 93), (6, 16), (0, 14)]
# Token Count [(',', 15), ('the', 9), ('.', 7)]
# Head Count [(7, 93), (9, 14), (3, 10)]
# Retrieved at rank 9 0.04648917782147284
# Layer Count [(7, 43), (2, 38), (8, 21)]
# Token Count [('a', 15), ('the', 14), ('.', 13)]
# Head Count [(7, 41), (9, 35), (3, 20)]
# Layer: (7, 43), Head: (7, 34)
# DE
# Retrieved at rank 0 0.008684438158189662
# Layer Count [(2, 71), (0, 21), (6, 5)]
# Token Count [('und', 8), ('.', 5), ('##e', 4)]
# Head Count [(7, 70), (9, 19), (3, 5)]
# Retrieved at rank 1 0.0036015655559984002
# Layer Count [(2, 84), (0, 25), (6, 1)]
# Token Count [('den', 6), ('##en', 6), ('und', 5)]
# Head Count [(7, 84), (9, 24), (5, 1)]
# Retrieved at rank 2 0.018667157681340044
# Layer Count [(2, 39), (11, 12), (0, 10)]
# Token Count [('das', 9), ('fahrer', 4), ('lenk', 4)]
# Head Count [(7, 40), (8, 13), (9, 10)]
# Retrieved at rank 3 0.009142114489975943
# Layer Count [(2, 58), (0, 21), (1, 10)]
# Token Count [('und', 8), ('##en', 5), ('.', 4)]
# Head Count [(7, 58), (9, 30), (11, 6)]
# Retrieved at rank 4 0.005437644108311875
# Layer Count [(2, 110), (0, 80), (6, 5)]
# Token Count [('der', 18), ('und', 13), ('.', 9)]
# Head Count [(7, 114), (9, 78), (10, 4)]
# Retrieved at rank 5 0.018993563790984887
# Layer Count [(2, 51), (0, 13), (11, 8)]
# Token Count [(',', 9), ('aktive', 5), ('und', 3)]
# Head Count [(7, 53), (9, 12), (8, 7)]
# Retrieved at rank 6 0.019514082081994916
# Layer Count [(2, 49), (11, 22), (0, 18)]
# Token Count [('die', 8), ('##en', 5), ('.', 5)]
# Head Count [(7, 55), (9, 18), (8, 16)]
# Retrieved at rank 7 0.009671917080211201
# Layer Count [(2, 97), (0, 35), (1, 1)]
# Token Count [(',', 12), ('der', 7), ('.', 6)]
# Head Count [(7, 98), (9, 33), (2, 1)]
# Retrieved at rank 8 0.012131222576752048
# Layer Count [(2, 71), (0, 23), (11, 6)]
# Token Count [('.', 8), ('aus', 5), ('der', 4)]
# Head Count [(7, 71), (9, 24), (8, 6)]
# Retrieved at rank 9 0.004139578332210174
# Layer Count [(2, 76), (0, 46), (1, 1)]
# Token Count [('der', 11), ('und', 10), ('.', 6)]
# Head Count [(7, 76), (9, 47), (11, 1)]
# Layer: (2, 71), Head: (7, 70)

# %%
query = 'adaptive Geschwindigkeitsregelung'
en_ret_docs, de_ret_docs = retrieve(query)
print("EN")
count = show_scores(en_ret_docs)
print(f"Layer: {Counter(count['layer']).most_common(1)[0][0]}, Head: {Counter(count['head']).most_common(1)[0][0]}")
print("DE")
count = show_scores(de_ret_docs)
print(f"Layer: {Counter(count['layer']).most_common(1)[0][0]}, Head: {Counter(count['head']).most_common(1)[0][0]}")
# Out:
# 100%|██████████| 100/100 [00:01<00:00, 90.92it/s]
# 100%|██████████| 100/100 [00:01<00:00, 87.61it/s]
# EN
# Retrieved at rank 0 0.03549626239652399
# Layer Count [(2, 34), (7, 30), (8, 22)]
# Token Count [(',', 20), ('to', 13), ('dense', 12)]
# Head Count [(7, 39), (9, 30), (8, 14)]
# Retrieved at rank 1 0.01750645690259295
# Layer Count [(2, 65), (6, 13), (0, 10)]
# Token Count [('the', 8), ('in', 7), ('and', 6)]
# Head Count [(7, 67), (11, 11), (9, 9)]
# Retrieved at rank 2 0.041019929976200555
# Layer Count [(7, 37), (2, 34), (5, 15)]
# Token Count [('to', 24), ('the', 23), ('preceding', 11)]
# Head Count [(7, 43), (9, 30), (3, 15)]
# Retrieved at rank 3 0.05170020736174518
# Layer Count [(2, 35), (7, 35), (5, 25)]
# Token Count [('the', 23), ('to', 18), ('flow', 16)]
# Head Count [(7, 34), (9, 27), (5, 18)]
# Retrieved at rank 4 0.024048274319439858
# Layer Count [(2, 53), (10, 12), (0, 11)]
# Token Count [('and', 9), ('.', 6), ('automatically', 6)]
# Head Count [(7, 54), (9, 28), (11, 12)]
# Retrieved at rank 5 0.01804908504518042
# Layer Count [(2, 89), (0, 16), (6, 8)]
# Token Count [(',', 13), ('the', 12), ('in', 6)]
# Head Count [(7, 89), (9, 15), (11, 7)]
# Retrieved at rank 6 0.03341004449497604
# Layer Count [(2, 44), (9, 13), (10, 9)]
# Token Count [('the', 13), ('.', 7), ('desired', 6)]
# Head Count [(7, 45), (1, 13), (9, 12)]
# Retrieved at rank 7 0.03348621062037726
# Layer Count [(2, 48), (9, 13), (7, 9)]
# Token Count [('the', 10), ('.', 7), ('distance', 5)]
# Head Count [(7, 52), (9, 13), (1, 11)]
# Retrieved at rank 8 0.02268699593781272
# Layer Count [(2, 69), (0, 11), (6, 7)]
# Token Count [('the', 9), (',', 8), ('.', 7)]
# Head Count [(7, 70), (9, 10), (11, 6)]
# Retrieved at rank 9 0.044357689365850404
# Layer Count [(7, 31), (2, 21), (8, 13)]
# Token Count [('the', 13), ('and', 10), (',', 9)]
# Head Count [(7, 23), (9, 20), (3, 14)]
# Layer: (2, 34), Head: (7, 39)
# DE
# Retrieved at rank 0 0.010430159347130631
# Layer Count [(2, 56), (0, 21), (6, 6)]
# Token Count [('.', 7), (',', 6), ('der', 5)]
# Head Count [(7, 59), (9, 20), (11, 6)]
# Retrieved at rank 1 0.008743564627018025
# Layer Count [(2, 58), (0, 22), (11, 5)]
# Token Count [(',', 6), ('das', 6), ('die', 6)]
# Head Count [(7, 59), (9, 20), (8, 4)]
# Retrieved at rank 2 0.0024900429587874653
# Layer Count [(2, 99), (0, 44), (6, 1)]
# Token Count [('die', 9), ('.', 7), ('der', 7)]
# Head Count [(7, 99), (9, 43), (5, 1)]
# Retrieved at rank 3 0.043372560289446374
# Layer Count [(7, 21), (2, 18), (0, 12)]
# Token Count [('die', 13), ('##sr', 10), ('pass', 10)]
# Head Count [(7, 26), (9, 20), (8, 10)]
# Retrieved at rank 4 0.008709577649150696
# Layer Count [(2, 48), (0, 17), (3, 5)]
# Token Count [('und', 5), ('die', 5), ('.', 4)]
# Head Count [(7, 49), (9, 16), (11, 3)]
# Retrieved at rank 5 0.0375542091849689
# Layer Count [(7, 48), (11, 28), (8, 21)]
# Token Count [('die', 27), ('an', 14), ('oder', 13)]
# Head Count [(7, 33), (9, 25), (8, 24)]
# Retrieved at rank 6 0.01629864371812341
# Layer Count [(2, 46), (0, 17), (6, 5)]
# Token Count [('die', 7), ('nach', 4), ('.', 4)]
# Head Count [(7, 45), (9, 16), (3, 5)]
# Retrieved at rank 7 0.013360760231205809
# Layer Count [(2, 52), (0, 19), (6, 7)]
# Token Count [('ein', 5), ('.', 4), ('zum', 4)]
# Head Count [(7, 53), (9, 18), (11, 6)]
# Retrieved at rank 8 0.028073063033707633
# Layer Count [(2, 34), (7, 20), (0, 9)]
# Token Count [('*', 10), ('und', 6), ('stop', 4)]
# Head Count [(7, 38), (9, 15), (3, 8)]
# Retrieved at rank 9 0.0014101107784253901
# Layer Count [(2, 69), (0, 43), (1, 1)]
# Token Count [('der', 10), ('.', 7), ('mit', 4)]
# Head Count [(7, 70), (9, 42), (5, 1)]
# Layer: (2, 56), Head: (7, 59)

# %% [markdown]
# **Observations**
# - mostly Layers **2** and **7** have heads where tokens attend to almost all the query tokens.
# - mostly Heads **7** and **9** where tokens attend to almost all the query tokens.
# - most of the articles, conjunctions and prepositions (a, an, and, die, der, mit, ) attend to all the query tokens.
